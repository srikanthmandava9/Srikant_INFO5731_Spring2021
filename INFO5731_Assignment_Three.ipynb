# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanthmandava9/Srikant_INFO5731_Spring2021/blob/master/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
#Install chromedrive, selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [602 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,745 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,396 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,163 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,964 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [893 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,394 kB]
# Fetched 11.4 MB in 4s (3,171 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 46 not upgraded.
# Need to get 81.0 MB of archives.
# After this operation, 273 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 87.0.4280.66-0ubuntu0.18.04.1 [1,122 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 87.0.4280.66-0ubuntu0.18.04.1 [71.7 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 87.0.4280.66-0ubuntu0.18.04.1 [3,716 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 87.0.4280.66-0ubuntu0.18.04.1 [4,488 kB]
# Fetched 81.0 MB in 3s (24.3 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_87.0.4280.66-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (87.0.4280.66-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_87.0.4280.66-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (87.0.4280.66-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_87.0.4280.66-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (87.0.4280.66-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_87.0.4280.66-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (87.0.4280.66-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (87.0.4280.66-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (87.0.4280.66-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (87.0.4280.66-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (87.0.4280.66-0ubuntu0.18.04.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 4.2MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
#Scapping data and converting to dataframe
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt10579952/reviews?ref_=tt_ov_rt'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
dataframe = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(dataframe)))
dataframe
# Out:
# Length of data frame is 125
#                                                  Title                                             Review
# 0                          JD & Bhavani Stole the Show  Perfect characteristation for both VIJAY & VJS...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  Vijay & VJS is Only Lifting The Whole Movie. A...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  Great thing is about the movie is VIJAY vs VIJ...
# 3                              Awesome awesome awesome
# 4    Commercial & Predictable potboiler!Much Disapp...
# ..                                                 ...                                                ...
# 120                                       Vijay vs VJS  Master's biggest plus point is vijay sethupath...
# 121                  MASTER : Vijay V/s Vijay Show !!!  The film is the story of JD (Thalapathy Vijay)...
# 122                                      awesome movie  LEGEND VS LEGEND.... definitely movie is Epic....
# 123  Master is a film that mainly depends on the br...  After proving his mettle as a filmmaker in his...
# 124                 Fabulous and full on entertainment  No words full on entertainment. Talapathay Vij...
#
# [125 rows x 2 columns]

# %%
# Download nltk all
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to /root/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Package comparative_sentences is already up-to-date!
#        | Downloading package comtrans to /root/nltk_data...
#        |   Package comtrans is already up-to-date!
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Package conll2002 is already up-to-date!
#        | Downloading package conll2007 to /root/nltk_data...
#        |   Package conll2007 is already up-to-date!
#        | Downloading package crubadan to /root/nltk_data...
#        |   Package crubadan is already up-to-date!
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Package dependency_treebank is already up-to-date!
#        | Downloading package dolch to /root/nltk_data...
#        |   Package dolch is already up-to-date!
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Package europarl_raw is already up-to-date!
#        | Downloading package floresta to /root/nltk_data...
#        |   Package floresta is already up-to-date!
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Package framenet_v15 is already up-to-date!
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Package framenet_v17 is already up-to-date!
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Package gazetteers is already up-to-date!
#        | Downloading package genesis to /root/nltk_data...
#        |   Package genesis is already up-to-date!
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Package gutenberg is already up-to-date!
#        | Downloading package ieer to /root/nltk_data...
#        |   Package ieer is already up-to-date!
#        | Downloading package inaugural to /root/nltk_data...
#        |   Package inaugural is already up-to-date!
#        | Downloading package indian to /root/nltk_data...
#        |   Package indian is already up-to-date!
#        | Downloading package jeita to /root/nltk_data...
#        |   Package jeita is already up-to-date!
#        | Downloading package kimmo to /root/nltk_data...
#        |   Package kimmo is already up-to-date!
#        | Downloading package knbc to /root/nltk_data...
#        |   Package knbc is already up-to-date!
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Package lin_thesaurus is already up-to-date!
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Package mac_morpho is already up-to-date!
#        | Downloading package machado to /root/nltk_data...
#        |   Package machado is already up-to-date!
#        | Downloading package masc_tagged to /root/nltk_data...
#        |   Package masc_tagged is already up-to-date!
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Package moses_sample is already up-to-date!
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Package movie_reviews is already up-to-date!
#        | Downloading package names to /root/nltk_data...
#        |   Package names is already up-to-date!
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        |   Package nombank.1.0 is already up-to-date!
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Package nps_chat is already up-to-date!
#        | Downloading package omw to /root/nltk_data...
#        |   Package omw is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Package opinion_lexicon is already up-to-date!
#        | Downloading package paradigms to /root/nltk_data...
#        |   Package paradigms is already up-to-date!
#        | Downloading package pil to /root/nltk_data...
#        |   Package pil is already up-to-date!
#        | Downloading package pl196x to /root/nltk_data...
#        |   Package pl196x is already up-to-date!
#        | Downloading package ppattach to /root/nltk_data...
#        |   Package ppattach is already up-to-date!
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Package problem_reports is already up-to-date!
#        | Downloading package propbank to /root/nltk_data...
#        |   Package propbank is already up-to-date!
#        | Downloading package ptb to /root/nltk_data...
#        |   Package ptb is already up-to-date!
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Package product_reviews_1 is already up-to-date!
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Package product_reviews_2 is already up-to-date!
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Package pros_cons is already up-to-date!
#        | Downloading package qc to /root/nltk_data...
#        |   Package qc is already up-to-date!
#        | Downloading package reuters to /root/nltk_data...
#        |   Package reuters is already up-to-date!
#        | Downloading package rte to /root/nltk_data...
#        |   Package rte is already up-to-date!
#        | Downloading package semcor to /root/nltk_data...
#        |   Package semcor is already up-to-date!
#        | Downloading package senseval to /root/nltk_data...
#        |   Package senseval is already up-to-date!
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Package sentiwordnet is already up-to-date!
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Package sentence_polarity is already up-to-date!
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Package shakespeare is already up-to-date!
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Package sinica_treebank is already up-to-date!
#        | Downloading package smultron to /root/nltk_data...
#        |   Package smultron is already up-to-date!
#        | Downloading package state_union to /root/nltk_data...
#        |   Package state_union is already up-to-date!
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Package subjectivity is already up-to-date!
#        | Downloading package swadesh to /root/nltk_data...
#        |   Package swadesh is already up-to-date!
#        | Downloading package switchboard to /root/nltk_data...
#        |   Package switchboard is already up-to-date!
#        | Downloading package timit to /root/nltk_data...
#        |   Package timit is already up-to-date!
#        | Downloading package toolbox to /root/nltk_data...
#        |   Package toolbox is already up-to-date!
#        | Downloading package treebank to /root/nltk_data...
#        |   Package treebank is already up-to-date!
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Package twitter_samples is already up-to-date!
#        | Downloading package udhr to /root/nltk_data...
#        |   Package udhr is already up-to-date!
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Package udhr2 is already up-to-date!
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Package unicode_samples is already up-to-date!
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        |   Package universal_treebanks_v20 is already up-to-date!
#        | Downloading package verbnet to /root/nltk_data...
#        |   Package verbnet is already up-to-date!
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Package verbnet3 is already up-to-date!
#        | Downloading package webtext to /root/nltk_data...
#        |   Package webtext is already up-to-date!
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Package wordnet_ic is already up-to-date!
#        | Downloading package words to /root/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /root/nltk_data...
#        |   Package ycoe is already up-to-date!
#        | Downloading package rslp to /root/nltk_data...
#        |   Package rslp is already up-to-date!
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Package maxent_treebank_pos_tagger is already up-to-date!
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Package universal_tagset is already up-to-date!
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Package maxent_ne_chunker is already up-to-date!
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Package book_grammars is already up-to-date!
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Package sample_grammars is already up-to-date!
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Package spanish_grammars is already up-to-date!
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Package basque_grammars is already up-to-date!
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Package large_grammars is already up-to-date!
#        | Downloading package tagsets to /root/nltk_data...
#        |   Package tagsets is already up-to-date!
#        | Downloading package snowball_data to /root/nltk_data...
#        |   Package snowball_data is already up-to-date!
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Package bllip_wsj_no_aux is already up-to-date!
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Package word2vec_sample is already up-to-date!
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        |   Package panlex_swadesh is already up-to-date!
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Package mte_teip5 is already up-to-date!
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger is already up-to-date!
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger_ru is already up-to-
#        |       date!
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Package perluniprops is already up-to-date!
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Package nonbreaking_prefixes is already up-to-date!
#        | Downloading package vader_lexicon to /root/nltk_data...
#        |   Package vader_lexicon is already up-to-date!
#        | Downloading package porter_test to /root/nltk_data...
#        |   Package porter_test is already up-to-date!
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Package wmt15_eval is already up-to-date!
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Package mwa_ppdb is already up-to-date!
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# # Data Cleaning

# %%
#Lowercase
dataframe['Lower Case'] = dataframe['Review'].apply(lambda y: " ".join(y.lower() for y in y.split()))
dataframe
# Out:
#                                                  Title  ...                               Removing Punctuation
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay  vjs ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay  vjs is only lifting the whole movie ani...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  masters biggest plus point is vijay sethupathi...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  the film is the story of jd thalapathy vijay a...
# 122                                      awesome movie  ...  legend vs legend definitely movie is epic both...
# 123  Master is a film that mainly depends on the br...  ...  after proving his mettle as a filmmaker in his...
# 124                 Fabulous and full on entertainment  ...  no words full on entertainment talapathay vija...
#
# [125 rows x 4 columns]

# %%
#Removing Punctuations
dataframe['Removing Punctuation'] = dataframe['Lower Case'].str.replace('[^\w\s]','')
dataframe
# Out:
#                                                  Title  ...                               Removing Punctuation
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay  vjs ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay  vjs is only lifting the whole movie ani...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  masters biggest plus point is vijay sethupathi...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  the film is the story of jd thalapathy vijay a...
# 122                                      awesome movie  ...  legend vs legend definitely movie is epic both...
# 123  Master is a film that mainly depends on the br...  ...  after proving his mettle as a filmmaker in his...
# 124                 Fabulous and full on entertainment  ...  no words full on entertainment talapathay vija...
#
# [125 rows x 4 columns]

# %%
#Removing special char
import re
dataframe['Removing Special Char'] = dataframe['Removing Punctuation'].apply(lambda y: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in y ))
dataframe
# Out:
#                                                  Title  ...                              Removing Special Char
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation for both vijay  vjs ...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay  vjs is only lifting the whole movie ani...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing is about the movie is vijay vs vij...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  masters biggest plus point is vijay sethupathi...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  the film is the story of jd thalapathy vijay a...
# 122                                      awesome movie  ...  legend vs legend definitely movie is epic both...
# 123  Master is a film that mainly depends on the br...  ...  after proving his mettle as a filmmaker in his...
# 124                 Fabulous and full on entertainment  ...  no words full on entertainment talapathay vija...
#
# [125 rows x 5 columns]

# %%
#Removing Stop words
from nltk.corpus import stopwords
stop = stopwords.words('english')
dataframe['Stopwords Removal'] = dataframe['Removing Punctuation'].apply(lambda y: " ".join(y for y in y.split() if y not in stop))
dataframe
# Out:
#                                                  Title  ...                                  Stopwords Removal
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation vijay vjs 2nd half l...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vijay vjs lifting whole movie anirudh bgm take...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing movie vijay vs vijay make u go cra...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  masters biggest plus point vijay sethupathi bh...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  film story jd thalapathy vijay drunkard profes...
# 122                                      awesome movie  ...  legend vs legend definitely movie epic actors ...
# 123  Master is a film that mainly depends on the br...  ...  proving mettle filmmaker previous outings maan...
# 124                 Fabulous and full on entertainment  ...  words full entertainment talapathay vijay rock...
#
# [125 rows x 6 columns]

# %%
#Spelling correction
from textblob import TextBlob
dataframe['Spelling Correction'] = dataframe['Stopwords Removal'].apply(lambda y: str(TextBlob(y).correct()))
dataframe
# Out:
#                                                  Title  ...                                Spelling Correction
# 0                          JD & Bhavani Stole the Show  ...  perfect characteristation vital vs and half li...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vital vs lifting whole movie anirudh by taken ...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing movie vital vs vital make u go cra...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  masters biggest plus point vital sethupathi bh...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  film story d thalapathy vital drunkard profess...
# 122                                      awesome movie  ...  legend vs legend definitely movie epic actors ...
# 123  Master is a film that mainly depends on the br...  ...  proving mettle filmmaker previous outing maana...
# 124                 Fabulous and full on entertainment  ...  words full entertainment talapathay vital rock...
#
# [125 rows x 7 columns]

# %%
#Tokenization
import nltk
nltk.download('punkt')
dataframe['Tokenization'] = dataframe['Spelling Correction'].apply(lambda y: TextBlob(y).words)
dataframe
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                  Title  ...                                       Tokenization
# 0                          JD & Bhavani Stole the Show  ...  [perfect, characteristation, vital, vs, and, h...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  [vital, vs, lifting, whole, movie, anirudh, by...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  [great, thing, movie, vital, vs, vital, make, ...
# 3                              Awesome awesome awesome  ...                                                 []
# 4    Commercial & Predictable potboiler!Much Disapp...  ...                                                 []
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  [masters, biggest, plus, point, vital, sethupa...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  [film, story, d, thalapathy, vital, drunkard, ...
# 122                                      awesome movie  ...  [legend, vs, legend, definitely, movie, epic, ...
# 123  Master is a film that mainly depends on the br...  ...  [proving, mettle, filmmaker, previous, outing,...
# 124                 Fabulous and full on entertainment  ...  [words, full, entertainment, talapathay, vital...
#
# [125 rows x 8 columns]

# %%
#Stemming
from nltk.stem import PorterStemmer
string = PorterStemmer()
dataframe['Stemming'] = dataframe['Tokenization'].apply(lambda y: " ".join([string.stem(word) for word in y]))
dataframe
# Out:
#                                                  Title  ...                                           Stemming
# 0                          JD & Bhavani Stole the Show  ...  perfect characterist vital vs and half littl b...
# 1                Vijay Sethupathi 🤜🏻🤛🏻 Thalapathy Show  ...  vital vs lift whole movi anirudh by taken holl...
# 2             GOOD STORYLINE WITH SLOW PACED NARRATION  ...  great thing movi vital vs vital make u go craz...
# 3                              Awesome awesome awesome  ...
# 4    Commercial & Predictable potboiler!Much Disapp...  ...
# ..                                                 ...  ...                                                ...
# 120                                       Vijay vs VJS  ...  master biggest plu point vital sethupathi bhav...
# 121                  MASTER : Vijay V/s Vijay Show !!!  ...  film stori d thalapathi vital drunkard profess...
# 122                                      awesome movie  ...  legend vs legend definit movi epic actor pione...
# 123  Master is a film that mainly depends on the br...  ...  prove mettl filmmak previou outing maanagaram ...
# 124                 Fabulous and full on entertainment  ...  word full entertain talapathay vital rock mast...
#
# [125 rows x 9 columns]

# %%
#Lemmination
from textblob import Word
import nltk
nltk.download('wordnet')

dataframe['Lemmatization'] = dataframe['Stemming'].apply(lambda y: " ".join([Word(word).lemmatize() for word in y.split()]))
dataframe.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sen = []
for sen in dataframe['Lemmatization']:
  words_sen.append(word_tokenize(sen))
aftercleaning = [y for y in words_sentence if y != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))
tri_gram = nltk.trigrams(iterations)
freq_dist = nltk.FreqDist(tri_gram)
freq_dist
# Out:
# FreqDist({('perfect', 'characterist', 'vital'): 1,
#           ('characterist', 'vital', 'v'): 1,
#           ('vital', 'v', 'and'): 1,
#           ('v', 'and', 'half'): 2,
#           ('and', 'half', 'littl'): 3,
#           ('half', 'littl', 'bit'): 2,
#           ('littl', 'bit', 'lag'): 1,
#           ('bit', 'lag', 'without'): 1,
#           ('lag', 'without', 'stori'): 1,
#           ('without', 'stori', 'moveexcept'): 1,
#           ('stori', 'moveexcept', 've'): 1,
#           ('moveexcept', 've', 'manner'): 1,
#           ('ve', 'manner', 'make'): 1,
#           ('manner', 'make', 'u'): 1,
#           ('make', 'u', 'crazi'): 1,
#           ('u', 'crazi', 'also'): 1,
#           ('crazi', 'also', 'v'): 1,
#           ('also', 'v', 'terrorist'): 1,
#           ('v', 'terrorist', 'haunt'): 1,
#           ('terrorist', 'haunt', 'worth'): 1,
#           ('haunt', 'worth', 'watch'): 1,
#           ('worth', 'watch', 'like'): 1,
#           ('watch', 'like', 'thalapathi'): 1,
#           ('like', 'thalapathi', 'move'): 1,
#           ('thalapathi', 'move', 'vital'): 1,
#           ('move', 'vital', 'given'): 1,
#           ('vital', 'given', 'imag'): 1,
#           ('given', 'imag', 'allow'): 1,
#           ('imag', 'allow', 'everyon'): 1,
#           ('allow', 'everyon', 'mock'): 1,
#           ('everyon', 'mock', 'sign'): 1,
#           ('mock', 'sign', 'helpless'): 1,
#           ('sign', 'helpless', 'actorclimax'): 1,
#           ('helpless', 'actorclimax', 'interv'): 1,
#           ('actorclimax', 'interv', 'block'): 1,
#           ('interv', 'block', 'terrificdont'): 1,
#           ('block', 'terrificdont', 'listen'): 1,
#           ('terrificdont', 'listen', 'neg'): 1,
#           ('listen', 'neg', 'reviewsit'): 1,
#           ('neg', 'reviewsit', 'pure'): 1,
#           ('reviewsit', 'pure', 'commerci'): 1,
#           ('pure', 'commerci', 'entertain'): 1,
#           ('commerci', 'entertain', 'decent'): 1,
#           ('entertain', 'decent', 'watchabl'): 1,
#           ('decent', 'watchabl', 'vital'): 1,
#           ('watchabl', 'vital', 'v'): 1,
#           ('vital', 'v', 'lift'): 1,
#           ('v', 'lift', 'whole'): 1,
#           ('lift', 'whole', 'movi'): 1,
#           ('whole', 'movi', 'anirudh'): 1,
#           ('movi', 'anirudh', 'by'): 1,
#           ('anirudh', 'by', 'taken'): 2,
#           ('by', 'taken', 'hollywood'): 2,
#           ('taken', 'hollywood', 'cinema'): 1,
#           ('hollywood', 'cinema', 'lokesh'): 1,
#           ('cinema', 'lokesh', 'god'): 1,
#           ('lokesh', 'god', 'screenplay'): 1,
#           ('god', 'screenplay', 'direct'): 1,
#           ('screenplay', 'direct', 'masterpiec'): 1,
#           ('direct', 'masterpiec', 'intermissionclimax'): 1,
#           ('masterpiec', 'intermissionclimax', '1sthalf'): 1,
#           ('intermissionclimax', '1sthalf', 'blockbuster2ndhalf'): 1,
#           ('1sthalf', 'blockbuster2ndhalf', 'superhit'): 1,
#           ('blockbuster2ndhalf', 'superhit', 'happi'): 1,
#           ('superhit', 'happi', 'master'): 1,
#           ('happi', 'master', 'postal'): 2,
#           ('master', 'postal', 'anna'): 1,
#           ('postal', 'anna', 'joy'): 1,
#           ('anna', 'joy', 'theatr'): 1,
#           ('joy', 'theatr', 'great'): 1,
#           ('theatr', 'great', 'thing'): 1,
#           ('great', 'thing', 'movi'): 1,
#           ('thing', 'movi', 'vital'): 1,
#           ('movi', 'vital', 'v'): 2,
#           ('vital', 'v', 'vital'): 2,
#           ('v', 'vital', 'make'): 1,
#           ('vital', 'make', 'u'): 1,
#           ('make', 'u', 'go'): 1,
#           ('u', 'go', 'crazi'): 1,
#           ('go', 'crazi', 'actingmalavika'): 1,
#           ('crazi', 'actingmalavika', 'andrew'): 1,
#           ('actingmalavika', 'andrew', 'good'): 1,
#           ('andrew', 'good', 'jobarjun'): 1,
#           ('good', 'jobarjun', 'da'): 1,
#           ('jobarjun', 'da', 'perfect'): 1,
#           ('da', 'perfect', 'role'): 1,
#           ('perfect', 'role', 'good'): 1,
#           ('role', 'good', 'storylin'): 1,
#           ('good', 'storylin', 'averag'): 1,
#           ('storylin', 'averag', 'screenplay'): 1,
#           ('averag', 'screenplay', 'director'): 1,
#           ('screenplay', 'director', 'chosen'): 1,
#           ('director', 'chosen', 'deal'): 1,
#           ('chosen', 'deal', 'stori'): 1,
#           ('deal', 'stori', 'nonlinear'): 1,
#           ('stori', 'nonlinear', 'narrat'): 1,
#           ('nonlinear', 'narrat', 'suitabl'): 1,
#           ('narrat', 'suitabl', 'stori'): 1,
#           ('suitabl', 'stori', 'line'): 1,
#           ('stori', 'line', 'want'): 1,
#           ('line', 'want', 'say'): 1,
#           ('want', 'say', 'want'): 1,
#           ('say', 'want', 'say'): 1,
#           ('want', 'say', 'storylin'): 1,
#           ('say', 'storylin', 'say'): 1,
#           ('storylin', 'say', 'one'): 1,
#           ('say', 'one', 'line'): 1,
#           ('one', 'line', 'actor'): 1,
#           ('line', 'actor', 'made'): 1,
#           ('actor', 'made', 'movi'): 1,
#           ('made', 'movi', 'interest'): 1,
#           ('movi', 'interest', 'final'): 1,
#           ('interest', 'final', 'good'): 1,
#           ('final', 'good', 'movi'): 1,
#           ('good', 'movi', 'slow'): 1,
#           ('movi', 'slow', 'pace'): 1,
#           ('slow', 'pace', 'narrat'): 1,
#           ('pace', 'narrat', 'one'): 1,
#           ('narrat', 'one', 'time'): 1,
#           ('one', 'time', 'watchabl'): 1,
#           ('time', 'watchabl', 'dont'): 1,
#           ('watchabl', 'dont', 'miss'): 1,
#           ('dont', 'miss', 'theatr'): 1,
#           ('miss', 'theatr', 'experi'): 1,
#           ('theatr', 'experi', 'boy'): 1,
#           ('experi', 'boy', 'movi'): 1,
#           ('boy', 'movi', 'make'): 1,
#           ('movi', 'make', 'u'): 1,
#           ('make', 'u', 'celebr'): 1,
#           ('u', 'celebr', 'long'): 1,
#           ('celebr', 'long', 'time'): 1,
#           ('long', 'time', 'anaem'): 1,
#           ('time', 'anaem', 'vjvj'): 1,
#           ('anaem', 'vjvj', 'mass'): 1,
#           ('vjvj', 'mass', 'act'): 1,
#           ('mass', 'act', 'st'): 1,
#           ('act', 'st', 'half'): 1,
#           ('st', 'half', 'vera'): 1,
#           ('half', 'vera', 'mari'): 1,
#           ('vera', 'mari', 'vera'): 1,
#           ('mari', 'vera', 'mari'): 1,
#           ('vera', 'mari', 'and'): 1,
#           ('mari', 'and', 'half'): 1,
#           ('and', 'half', 'ok'): 1,
#           ('half', 'ok', 'superb'): 1,
#           ('ok', 'superb', 'untruth'): 1,
#           ('superb', 'untruth', 'by'): 1,
#           ('untruth', 'by', 'rock'): 1,
#           ('by', 'rock', 'love'): 1,
#           ('rock', 'love', 'direct'): 1,
#           ('love', 'direct', 'differ'): 1,
#           ('direct', 'differ', 'thank'): 1,
#           ('differ', 'thank', 'u'): 1,
#           ('thank', 'u', 'thalaivaa'): 1,
#           ('u', 'thalaivaa', 'enjoy'): 1,
#           ('thalaivaa', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'happi'): 1,
#           ('movi', 'happi', 'master'): 1,
#           ('master', 'postal', 'stori'): 1,
#           ('postal', 'stori', 'someth'): 1,
#           ('stori', 'someth', 'differ'): 2,
#           ('someth', 'differ', 'somewhat'): 2,
#           ('differ', 'somewhat', 'hope'): 2,
#           ('somewhat', 'hope', 'well'): 2,
#           ('hope', 'well', 'made'): 2,
#           ('well', 'made', 'commerci'): 2,
#           ('made', 'commerci', 'way'): 2,
#           ('commerci', 'way', 'appeal'): 2,
#           ('way', 'appeal', 'fan'): 2,
#           ('appeal', 'fan', 'miss'): 2,
#           ('fan', 'miss', 'theater'): 2,
#           ('miss', 'theater', 'found'): 2,
#           ('theater', 'found', 'better'): 2,
#           ('found', 'better', 'vila'): 2,
#           ('better', 'vila', 'previou'): 2,
#           ('vila', 'previou', 'move'): 2,
#           ('previou', 'move', 'like'): 2,
#           ('move', 'like', 'vigil'): 2,
#           ('like', 'vigil', 'makar'): 2,
#           ('vigil', 'makar', 'find'): 2,
#           ('makar', 'find', 'love'): 2,
#           ('find', 'love', 'touch'): 2,
#           ('love', 'touch', 'film'): 2,
#           ('touch', 'film', 'may'): 2,
#           ('film', 'may', 'like'): 2,
#           ('may', 'like', 'maanagaram'): 2,
#           ('like', 'maanagaram', 'faith'): 2,
#           ('maanagaram', 'faith', 'still'): 2,
#           ('faith', 'still', 'worth'): 2,
#           ('still', 'worth', 'watch'): 2,
#           ('worth', 'watch', 'movi'): 3,
#           ('watch', 'movi', 'stori'): 3,
#           ('movi', 'stori', 'direct'): 2,
#           ('stori', 'direct', 'perform'): 2,
#           ('direct', 'perform', 'vital'): 2,
#           ('perform', 'vital', 'v'): 2,
#           ('vital', 'v', 'everyon'): 1,
#           ('v', 'everyon', 'must'): 1,
#           ('everyon', 'must', 'watch'): 1,
#           ('must', 'watch', 'theater'): 1,
#           ('watch', 'theater', 'also'): 1,
#           ('theater', 'also', 'watch'): 1,
#           ('also', 'watch', 'month'): 1,
#           ('watch', 'month', 'to'): 1,
#           ('month', 'to', 'u'): 1,
#           ('to', 'u', 'wont'): 1,
#           ('u', 'wont', 'get'): 1,
#           ('wont', 'get', 'feel'): 1,
#           ('get', 'feel', 'theater'): 1,
#           ('feel', 'theater', 'movi'): 1,
#           ('theater', 'movi', 'awesom'): 1,
#           ('movi', 'awesom', 'movi'): 1,
#           ('awesom', 'movi', 'vera'): 1,
#           ('movi', 'vera', 'level'): 2,
#           ('vera', 'level', 'big'): 1,
#           ('level', 'big', 'treat'): 1,
#           ('big', 'treat', 'thalapathi'): 1,
#           ('treat', 'thalapathi', 'fan'): 1,
#           ('thalapathi', 'fan', 'enjoy'): 1,
#           ('fan', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'time'): 1,
#           ('movi', 'time', 'long'): 1,
#           ('time', 'long', 'gap'): 1,
#           ('long', 'gap', 'enjoy'): 1,
#           ('gap', 'enjoy', 'everi'): 1,
#           ('enjoy', 'everi', 'bit'): 1,
#           ('everi', 'bit', 'movi'): 1,
#           ('bit', 'movi', 'super'): 1,
#           ('movi', 'super', 'movi'): 2,
#           ('super', 'movi', 'fan'): 1,
#           ('movi', 'fan', 'enjoy'): 1,
#           ('fan', 'enjoy', 'fullfamili'): 1,
#           ('enjoy', 'fullfamili', 'audienc'): 1,
#           ('fullfamili', 'audienc', 'ku'): 1,
#           ('audienc', 'ku', 'belaya'): 1,
#           ('ku', 'belaya', 'enjoy'): 1,
#           ('belaya', 'enjoy', 'irukum'): 1,
#           ('enjoy', 'irukum', 'movi'): 1,
#           ('irukum', 'movi', 'thalapathi'): 1,
#           ('movi', 'thalapathi', 'v'): 1,
#           ('thalapathi', 'v', 'vera'): 1,
#           ('v', 'vera', 'level'): 1,
#           ('vera', 'level', 'and'): 1,
#           ('level', 'and', 'by'): 1,
#           ('and', 'by', 'tharumaru'): 1,
#           ('by', 'tharumaru', 'loi'): 1,
#           ('tharumaru', 'loi', 'posit'): 1,
#           ('loi', 'posit', 'main'): 1,
#           ('posit', 'main', 'lead'): 1,
#           ('main', 'lead', 'plot'): 1,
#           ('lead', 'plot', 'song'): 1,
#           ('plot', 'song', 'n'): 1,
#           ('song', 'n', 'by'): 1,
#           ('n', 'by', 'direct'): 1,
#           ('by', 'direct', 'neg'): 1,
#           ('direct', 'neg', 'flat'): 1,
#           ('neg', 'flat', 'screenplay'): 1,
#           ('flat', 'screenplay', 'import'): 1,
#           ('screenplay', 'import', 'femal'): 1,
#           ('import', 'femal', 'lead'): 1,
#           ('femal', 'lead', '20'): 1,
#           ('lead', '20', 'minut'): 1,
#           ('20', 'minut', 'lengthi'): 1,
#           ('minut', 'lengthi', 'twist'): 1,
#           ('lengthi', 'twist', 'turn'): 1,
#           ('twist', 'turn', 'straight'): 1,
#           ('turn', 'straight', 'movi'): 1,
#           ('straight', 'movi', 'lot'): 1,
#           ('movi', 'lot', 'mass'): 1,
#           ('lot', 'mass', 'content'): 1,
#           ('mass', 'content', 'actor'): 1,
#           ('content', 'actor', 'play'): 1,
#           ('actor', 'play', 'role'): 1,
#           ('play', 'role', 'well'): 1,
#           ('role', 'well', 'vital'): 1,
#           ('well', 'vital', 'cool'): 1,
#           ('vital', 'cool', 'teacher'): 1,
#           ('cool', 'teacher', 'vital'): 1,
#           ('teacher', 'vital', 'sethupathi'): 1,
#           ('vital', 'sethupathi', 'terrifi'): 1,
#           ('sethupathi', 'terrifi', 'villain'): 1,
#           ('terrifi', 'villain', 'expect'): 1,
#           ('villain', 'expect', 'love'): 1,
#           ('expect', 'love', 'kanagaraj'): 1,
#           ('love', 'kanagaraj', 'movi'): 2,
#           ('kanagaraj', 'movi', 'ok'): 1,
#           ('movi', 'ok', 'movi'): 1,
#           ('ok', 'movi', 'antrum'): 1,
#           ('movi', 'antrum', 'music'): 1,
#           ('antrum', 'music', 'pu'): 1,
#           ('music', 'pu', 'magnum'): 1,
#           ('pu', 'magnum', 'overal'): 1,
#           ('magnum', 'overal', 'good'): 1,
#           ('overal', 'good', 'fan'): 1,
#           ('good', 'fan', 'ordinari'): 1,
#           ('fan', 'ordinari', 'fan'): 1,
#           ('ordinari', 'fan', 'ok'): 1,
#           ('fan', 'ok', 'sure'): 1,
#           ('ok', 'sure', 'watchabl'): 1,
#           ('sure', 'watchabl', 'love'): 1,
#           ('watchabl', 'love', 'way'): 1,
#           ('love', 'way', 'd'): 1,
#           ('way', 'd', 'live'): 1,
#           ('d', 'live', 'move'): 1,
#           ('live', 'move', 'stori'): 1,
#           ('move', 'stori', 'line'): 1,
#           ('stori', 'line', 'evil'): 1,
#           ('line', 'evil', 'havana'): 1,
#           ('evil', 'havana', 'realli'): 1,
#           ('havana', 'realli', 'masterpiec'): 1,
#           ('realli', 'masterpiec', 'master'): 1,
#           ('masterpiec', 'master', 'team'): 1,
#           ('master', 'team', 'everyon'): 1,
#           ('team', 'everyon', 'job'): 1,
#           ('everyon', 'job', 'well'): 1,
#           ('job', 'well', 'final'): 1,
#           ('well', 'final', 'celebr'): 1,
#           ('final', 'celebr', 'master'): 1,
#           ('celebr', 'master', 'brilliant'): 1,
#           ('master', 'brilliant', 'exampl'): 1,
#           ('brilliant', 'exampl', 'perfect'): 1,
#           ('exampl', 'perfect', 'cat'): 1,
#           ('perfect', 'cat', 'mous'): 1,
#           ('cat', 'mous', 'actionthril'): 1,
#           ('mous', 'actionthril', 'director'): 1,
#           ('actionthril', 'director', 'love'): 1,
#           ('director', 'love', 'gave'): 1,
#           ('love', 'gave', 'u'): 1,
#           ('gave', 'u', 'promis'): 1,
#           ('u', 'promis', 'master'): 1,
#           ('promis', 'master', 'break'): 1,
#           ('master', 'break', 'cliché'): 1,
#           ('break', 'cliché', 'typic'): 1,
#           ('cliché', 'typic', 'thalapathi'): 1,
#           ('typic', 'thalapathi', 'movi'): 1,
#           ('thalapathi', 'movi', 'usual'): 1,
#           ('movi', 'usual', 'kept'): 1,
#           ('usual', 'kept', 'promis'): 1,
#           ('kept', 'promis', 'master'): 1,
#           ('promis', 'master', 'clash'): 1,
#           ('master', 'clash', 'protagonist'): 1,
#           ('clash', 'protagonist', 'antagonist'): 1,
#           ('protagonist', 'antagonist', 'isn'): 1,
#           ('antagonist', 'isn', 'usual'): 1,
#           ('isn', 'usual', 'clash'): 1,
#           ('usual', 'clash', 'see'): 1,
#           ('clash', 'see', 'mani'): 1,
#           ('see', 'mani', 'tail'): 1,
#           ('mani', 'tail', 'move'): 1,
#           ('tail', 'move', 'stori'): 1,
#           ('move', 'stori', 'differ'): 1,
#           ('stori', 'differ', 'love'): 1,
#           ('differ', 'love', 'written'): 1,
#           ('love', 'written', 'charact'): 1,
#           ('written', 'charact', 'antagonist'): 1,
#           ('charact', 'antagonist', 'havana'): 1,
#           ('antagonist', 'havana', 'amount'): 1,
#           ('havana', 'amount', 'brillianc'): 1,
#           ('amount', 'brillianc', 'power'): 1,
#           ('brillianc', 'power', 'protagonist'): 1,
#           ('power', 'protagonist', 'd'): 1,
#           ('protagonist', 'd', 'vital'): 1,
#           ('d', 'vital', 'sethupathi'): 1,
#           ('vital', 'sethupathi', 'fail'): 1,
#           ('sethupathi', 'fail', 'role'): 1,
#           ('fail', 'role', 'devilish'): 1,
#           ('role', 'devilish', 'antagonist'): 1,
#           ('devilish', 'antagonist', 'whenev'): 1,
#           ('antagonist', 'whenev', 'appear'): 1,
#           ('whenev', 'appear', 'screen'): 1,
#           ('appear', 'screen', 'blast'): 1,
#           ('screen', 'blast', 'manner'): 1,
#           ('blast', 'manner', 'dialogu'): 1,
#           ('manner', 'dialogu', 'deliveri'): 1,
#           ('dialogu', 'deliveri', 'emot'): 1,
#           ('deliveri', 'emot', 'deliv'): 1,
#           ('emot', 'deliv', 'charact'): 1,
#           ('deliv', 'charact', 'spoon'): 1,
#           ('charact', 'spoon', 'last'): 1,
#           ('spoon', 'last', 'least'): 1,
#           ('last', 'least', 'thalapathi'): 1,
#           ('least', 'thalapathi', 'prove'): 1,
#           ('thalapathi', 'prove', 'prowess'): 1,
#           ('prove', 'prowess', 'excel'): 1,
#           ('prowess', 'excel', 'actor'): 1,
#           ('excel', 'actor', 'fanci'): 1,
#           ('actor', 'fanci', 'insid'): 1,
#           ('fanci', 'insid', 'rejoic'): 1,
#           ('insid', 'rejoic', 'broke'): 1,
#           ('rejoic', 'broke', 'cliché'): 1,
#           ('broke', 'cliché', 'dialogu'): 1,
#           ('cliché', 'dialogu', 'fight'): 1,
#           ('dialogu', 'fight', 'express'): 1,
#           ('fight', 'express', 'charact'): 1,
#           ('express', 'charact', 'd'): 1,
#           ('charact', 'd', 'uniqu'): 1,
#           ('d', 'uniqu', 'broke'): 1,
#           ('uniqu', 'broke', 'stereotyp'): 1,
#           ('broke', 'stereotyp', 'ador'): 1,
#           ('stereotyp', 'ador', 'everi'): 1,
#           ('ador', 'everi', 'moment'): 1,
#           ('everi', 'moment', 'live'): 1,
#           ('moment', 'live', 'john'): 1,
#           ('live', 'john', 'durairaj'): 1,
#           ('john', 'durairaj', 'screen'): 1,
#           ('durairaj', 'screen', 'technic'): 1,
#           ('screen', 'technic', 'crew'): 1,
#           ('technic', 'crew', 'master'): 1,
#           ('crew', 'master', 'deserv'): 1,
#           ('master', 'deserv', 'stand'): 1,
#           ('deserv', 'stand', 'orat'): 1,
#           ('stand', 'orat', 'extraordinari'): 1,
#           ('orat', 'extraordinari', 'work'): 1,
#           ('extraordinari', 'work', 'they'): 1,
#           ('work', 'they', 'done'): 1,
#           ('they', 'done', 'background'): 1,
#           ('done', 'background', 'score'): 1,
#           ('background', 'score', 'master'): 1,
#           ('score', 'master', 'one'): 1,
#           ('master', 'one', 'best'): 1,
#           ('one', 'best', 'composit'): 1,
#           ('best', 'composit', 'anirudh'): 1,
#           ('composit', 'anirudh', 'career'): 1,
#           ('anirudh', 'career', 'second'): 1,
#           ('career', 'second', 'protagonist'): 1,
#           ('second', 'protagonist', 'movi'): 1,
#           ('protagonist', 'movi', 'satan'): 1,
#           ('movi', 'satan', 'sooriyan'): 1,
#           ('satan', 'sooriyan', 'visual'): 1,
#           ('sooriyan', 'visual', 'anoth'): 1,
#           ('visual', 'anoth', 'highlight'): 1,
#           ('anoth', 'highlight', 'cinematographi'): 1,
#           ('highlight', 'cinematographi', 'topnotch'): 1,
#           ('cinematographi', 'topnotch', 'uniqu'): 1,
#           ('topnotch', 'uniqu', 'special'): 1,
#           ('uniqu', 'special', 'prais'): 1,
#           ('special', 'prais', 'stung'): 1,
#           ('prais', 'stung', 'master'): 1,
#           ('stung', 'master', 'sila'): 1,
#           ('master', 'sila', 'give'): 1,
#           ('sila', 'give', 'u'): 1,
#           ('give', 'u', 'class'): 1,
#           ('u', 'class', 'realist'): 1,
#           ('class', 'realist', 'action'): 1,
#           ('realist', 'action', 'sequenc'): 1,
#           ('action', 'sequenc', 'action'): 1,
#           ('sequenc', 'action', 'scene'): 1,
#           ('action', 'scene', 'sound'): 1,
#           ('scene', 'sound', 'master'): 1,
#           ('sound', 'master', 'amaz'): 1,
#           ('master', 'amaz', 'thuppakki'): 1,
#           ('amaz', 'thuppakki', 'that'): 1,
#           ('thuppakki', 'that', 'big'): 1,
#           ('that', 'big', 'statement'): 1,
#           ('big', 'statement', 'overal'): 1,
#           ('statement', 'overal', 'master'): 1,
#           ('overal', 'master', '50'): 1,
#           ('master', '50', 'love'): 1,
#           ('50', 'love', 'film'): 2,
#           ('love', 'film', '50'): 1,
#           ('film', '50', 'thalapathi'): 1,
#           ('50', 'thalapathi', 'vila'): 1,
#           ('thalapathi', 'vila', 'film'): 1,
#           ('vila', 'film', 'dont'): 2,
#           ('film', 'dont', 'think'): 1,
#           ('dont', 'think', 'anyon'): 1,
#           ('think', 'anyon', 'would'): 1,
#           ('anyon', 'would', 'hate'): 1,
#           ('would', 'hate', 'movi'): 1,
#           ('hate', 'movi', 'best'): 1,
#           ('movi', 'best', 'blend'): 1,
#           ('best', 'blend', 'mass'): 1,
#           ('blend', 'mass', 'class'): 1,
#           ('mass', 'class', 'movi'): 1,
#           ('class', 'movi', 'complet'): 1,
#           ('movi', 'complet', 'mass'): 1,
#           ('complet', 'mass', 'nasal'): 3,
#           ('mass', 'nasal', 'entertain'): 3,
#           ('nasal', 'entertain', 'long'): 1,
#           ('entertain', 'long', 'time'): 1,
#           ('long', 'time', 'indian'): 1,
#           ('time', 'indian', 'cinema'): 1,
#           ('indian', 'cinema', 'industri'): 1,
#           ('cinema', 'industri', 'got'): 1,
#           ('industri', 'got', 'wonder'): 1,
#           ('got', 'wonder', 'movi'): 1,
#           ('wonder', 'movi', 'worth'): 1,
#           ('movi', 'worth', 'watch'): 2,
#           ('worth', 'watch', 'nice'): 2,
#           ('watch', 'nice', 'movi'): 1,
#           ('nice', 'movi', 'worth'): 1,
#           ('watch', 'nice', 'act'): 1,
#           ('nice', 'act', 'good'): 1,
#           ('act', 'good', 'direct'): 1,
#           ('good', 'direct', 'best'): 1,
#           ('direct', 'best', 'action'): 1,
#           ('best', 'action', 'scene'): 1,
#           ('action', 'scene', 'first'): 1,
#           ('scene', 'first', 'refresh'): 1,
#           ('first', 'refresh', 'see'): 1,
#           ('refresh', 'see', 'vital'): 2,
#           ('see', 'vital', 'tri'): 1,
#           ('vital', 'tri', 'someth'): 1,
#           ('tri', 'someth', 'differ'): 1,
#           ('someth', 'differ', 'movi'): 1,
#           ('differ', 'movi', 'mass'): 1,
#           ('movi', 'mass', 'element'): 1,
#           ('mass', 'element', 'emot'): 1,
#           ('element', 'emot', 'littl'): 1,
#           ('emot', 'littl', 'bit'): 1,
#           ('littl', 'bit', 'top'): 1,
#           ('bit', 'top', 'action'): 1,
#           ('top', 'action', 'there'): 1,
#           ('action', 'there', 'uniqu'): 1,
#           ('there', 'uniqu', 'element'): 1,
#           ('uniqu', 'element', 'even'): 1,
#           ('element', 'even', 'vital'): 1,
#           ('even', 'vital', 'look'): 1,
#           ('vital', 'look', 'total'): 1,
#           ('look', 'total', 'differ'): 1,
#           ('total', 'differ', 'person'): 1,
#           ('differ', 'person', 'embodi'): 1,
#           ('person', 'embodi', 'charact'): 1,
#           ('embodi', 'charact', 'didn'): 1,
#           ('charact', 'didn', 'like'): 1,
#           ('didn', 'like', 'abl'): 1,
#           ('like', 'abl', 'move'): 1,
#           ('abl', 'move', 'sure'): 1,
#           ('move', 'sure', 'entertain'): 1,
#           ('sure', 'entertain', 'patch'): 1,
#           ('entertain', 'patch', 'great'): 1,
#           ('patch', 'great', 'allmast'): 1,
#           ('great', 'allmast', 'contrari'): 1,
#           ('allmast', 'contrari', 'might'): 1,
#           ('contrari', 'might', 'celebr'): 1,
#           ('might', 'celebr', 'move'): 1,
#           ('celebr', 'move', 'time'): 1,
#           ('move', 'time', 'fan'): 1,
#           ('time', 'fan', 'appreci'): 1,
#           ('fan', 'appreci', 'harsh'): 1,
#           ('appreci', 'harsh', 'realiti'): 1,
#           ('harsh', 'realiti', 'showcas'): 1,
#           ('realiti', 'showcas', 'life'): 1,
#           ('showcas', 'life', 'age'): 1,
#           ('life', 'age', 'peopl'): 1,
#           ('age', 'peopl', 'crime'): 1,
#           ('peopl', 'crime', 'exploit'): 1,
#           ('crime', 'exploit', 'thing'): 1,
#           ('exploit', 'thing', 'peopl'): 1,
#           ('thing', 'peopl', 'influenc'): 1,
#           ('peopl', 'influenc', 'life'): 1,
#           ('influenc', 'life', 'overal'): 1,
#           ('life', 'overal', 'great'): 1,
#           ('overal', 'great', 'watch'): 1,
#           ('great', 'watch', 'mani'): 1,
#           ('watch', 'mani', 'might'): 1,
#           ('mani', 'might', 'like'): 1,
#           ('might', 'like', 'perfect'): 1,
#           ('like', 'perfect', 'time'): 1,
#           ('perfect', 'time', 'till'): 1,
#           ('time', 'till', 'get'): 1,
#           ('till', 'get', 'recognit'): 1,
#           ('get', 'recognit', 'deserv'): 1,
#           ('recognit', 'deserv', 'one'): 1,
#           ('deserv', 'one', 'thing'): 1,
#           ('one', 'thing', 'vital'): 1,
#           ('thing', 'vital', 'sethubathi'): 1,
#           ('vital', 'sethubathi', 'fantast'): 1,
#           ('sethubathi', 'fantast', 'realli'): 1,
#           ('fantast', 'realli', 'good'): 1,
#           ('realli', 'good', 'soviet'): 1,
#           ('good', 'soviet', 'emot'): 1,
#           ('soviet', 'emot', 'action'): 1,
#           ('emot', 'action', 'also'): 1,
#           ('action', 'also', 'littl'): 1,
#           ('also', 'littl', 'bit'): 1,
#           ('littl', 'bit', 'love'): 1,
#           ('bit', 'love', 'stori'): 1,
#           ('love', 'stori', 'hatsoff'): 1,
#           ('stori', 'hatsoff', 'effort'): 1,
#           ('hatsoff', 'effort', 'vila'): 1,
#           ('effort', 'vila', 'never'): 1,
#           ('vila', 'never', 'seen'): 1,
#           ('never', 'seen', 'perform'): 1,
#           ('seen', 'perform', 'side'): 1,
#           ('perform', 'side', 'anirith'): 1,
#           ('side', 'anirith', 'good'): 1,
#           ('anirith', 'good', 'job'): 1,
#           ('good', 'job', 'stori'): 1,
#           ('job', 'stori', 'part'): 1,
#           ('stori', 'part', 'mass'): 1,
#           ('part', 'mass', 'scene'): 1,
#           ('mass', 'scene', 'screenplay'): 1,
#           ('scene', 'screenplay', 'worst'): 1,
#           ('screenplay', 'worst', 'part'): 1,
#           ('worst', 'part', 'movi'): 1,
#           ('part', 'movi', 'even'): 1,
#           ('movi', 'even', 'mani'): 1,
#           ('even', 'mani', 'charact'): 1,
#           ('mani', 'charact', 'nobodi'): 1,
#           ('charact', 'nobodi', 'charact'): 1,
#           ('nobodi', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'well'): 1,
#           ('develop', 'well', 'stori'): 1,
#           ('well', 'stori', 'line'): 1,
#           ('stori', 'line', 'track'): 1,
#           ('line', 'track', 'everybodi'): 1,
#           ('track', 'everybodi', 'come'): 1,
#           ('everybodi', 'come', 'mass'): 1,
#           ('come', 'mass', 'element'): 1,
#           ('mass', 'element', 'stori'): 1,
#           ('element', 'stori', 'line'): 1,
#           ('stori', 'line', 'movi'): 1,
#           ('line', 'movi', 'celebr'): 1,
#           ('movi', 'celebr', 'fan'): 1,
#           ('celebr', 'fan', 'vila'): 1,
#           ('fan', 'vila', 'manual'): 1,
#           ('vila', 'manual', 'sylvan'): 1,
#           ('manual', 'sylvan', 'attitud'): 1,
#           ('sylvan', 'attitud', 'superb'): 1,
#           ('attitud', 'superb', 'thalapathi'): 1,
#           ('superb', 'thalapathi', 'mass'): 1,
#           ('thalapathi', 'mass', 'e'): 1,
#           ('mass', 'e', 'entertain'): 1,
#           ('e', 'entertain', 'r'): 1,
#           ('entertain', 'r', 'record'): 1,
#           ('r', 'record', 'wast'): 1,
#           ('record', 'wast', 'money'): 1,
#           ('wast', 'money', 'timew'): 1,
#           ('money', 'timew', 'ff'): 1,
#           ('timew', 'ff', 'shout'): 1,
#           ('ff', 'shout', 'worth'): 1,
#           ('shout', 'worth', 'allow'): 1,
#           ('worth', 'allow', 'hope'): 1,
#           ('allow', 'hope', 'rate'): 1,
#           ('hope', 'rate', 'movienot'): 1,
#           ('rate', 'movienot', 'love'): 1,
#           ('movienot', 'love', 'movi'): 1,
#           ('love', 'movi', 'one'): 1,
#           ('movi', 'one', 'await'): 1,
#           ('one', 'await', 'anticip'): 1,
#           ('await', 'anticip', 'movi'): 1,
#           ('anticip', 'movi', 'past'): 1,
#           ('movi', 'past', 'two'): 1,
#           ('past', 'two', 'year'): 1,
#           ('two', 'year', 'master'): 1,
#           ('year', 'master', 'hit'): 1,
#           ('master', 'hit', 'screen'): 1,
#           ('hit', 'screen', 'lead'): 1,
#           ('screen', 'lead', 'role'): 1,
#           ('lead', 'role', 'play'): 1,
#           ('role', 'play', 'protagonist'): 1,
#           ('play', 'protagonist', 'thalapathi'): 1,
#           ('protagonist', 'thalapathi', 'vital'): 1,
#           ('thalapathi', 'vital', 'antagonist'): 1,
#           ('vital', 'antagonist', 'manual'): 1,
#           ('antagonist', 'manual', 'sylvan'): 1,
#           ('manual', 'sylvan', 'vital'): 2,
#           ('sylvan', 'vital', 'sethupathi'): 1,
#           ('vital', 'sethupathi', 'although'): 1,
#           ('sethupathi', 'although', 'film'): 1,
#           ('although', 'film', 'clash'): 1,
#           ('film', 'clash', 'two'): 1,
#           ('clash', 'two', 'vital'): 1,
#           ('two', 'vital', 'lot'): 1,
#           ('vital', 'lot', 'charact'): 1,
#           ('lot', 'charact', 'act'): 1,
#           ('charact', 'act', 'role'): 1,
#           ('act', 'role', 'well'): 1,
#           ('role', 'well', 'plotwis'): 1,
#           ('well', 'plotwis', 'firsthalf'): 1,
#           ('plotwis', 'firsthalf', 'play'): 1,
#           ('firsthalf', 'play', 'import'): 1,
#           ('play', 'import', 'part'): 1,
#           ('import', 'part', 'establish'): 1,
#           ('part', 'establish', 'charact'): 1,
#           ('establish', 'charact', 'maintain'): 1,
#           ('charact', 'maintain', 'pace'): 1,
#           ('maintain', 'pace', 'keep'): 1,
#           ('pace', 'keep', 'audienc'): 1,
#           ('keep', 'audienc', 'entertain'): 1,
#           ('audienc', 'entertain', 'john'): 1,
#           ('entertain', 'john', 'dhurairaj'): 1,
#           ('john', 'dhurairaj', 'vijayquirki'): 1,
#           ('dhurairaj', 'vijayquirki', 'funni'): 1,
#           ('vijayquirki', 'funni', 'charact'): 1,
#           ('funni', 'charact', 'vila'): 1,
#           ('charact', 'vila', 'overal'): 1,
#           ('vila', 'overal', 'outstand'): 1,
#           ('overal', 'outstand', 'screenpres'): 1,
#           ('outstand', 'screenpres', 'second'): 1,
#           ('screenpres', 'second', 'half'): 1,
#           ('second', 'half', 'speed'): 1,
#           ('half', 'speed', 'stick'): 1,
#           ('speed', 'stick', 'plot'): 1,
#           ('stick', 'plot', 'keep'): 1,
#           ('plot', 'keep', 'humour'): 1,
#           ('keep', 'humour', 'bundl'): 1,
#           ('humour', 'bundl', 'within'): 1,
#           ('bundl', 'within', 'stori'): 1,
#           ('within', 'stori', 'elev'): 1,
#           ('stori', 'elev', 'interv'): 1,
#           ('elev', 'interv', 'good'): 1,
#           ('interv', 'good', 'addit'): 1,
#           ('good', 'addit', 'film'): 1,
#           ('addit', 'film', 'anirudh'): 1,
#           ('film', 'anirudh', 'gift'): 1,
#           ('anirudh', 'gift', 'industri'): 1,
#           ('gift', 'industri', 'background'): 1,
#           ('industri', 'background', 'score'): 1,
#           ('background', 'score', 'elev'): 1,
#           ('score', 'elev', 'scene'): 1,
#           ('elev', 'scene', 'give'): 1,
#           ('scene', 'give', 'audienc'): 1,
#           ('give', 'audienc', 'twice'): 1,
#           ('audienc', 'twice', 'amount'): 1,
#           ('twice', 'amount', 'impact'): 1,
#           ('amount', 'impact', 'scene'): 1,
#           ('impact', 'scene', 'song'): 1,
#           ('scene', 'song', 'film'): 1,
#           ('song', 'film', 'use'): 1,
#           ('film', 'use', 'background'): 1,
#           ('use', 'background', 'speak'): 1,
#           ('background', 'speak', 'song'): 1,
#           ('speak', 'song', 'seem'): 1,
#           ('song', 'seem', 'lack'): 1,
#           ('seem', 'lack', 'better'): 1,
#           ('lack', 'better', 'placement'): 1,
#           ('better', 'placement', 'induc'): 1,
#           ('placement', 'induc', 'littl'): 1,
#           ('induc', 'littl', 'law'): 1,
#           ('littl', 'law', 'film'): 1,
#           ('law', 'film', 'main'): 1,
#           ('film', 'main', 'question'): 1,
#           ('main', 'question', 'love'): 1,
#           ('question', 'love', 'kanagaraj'): 1,
#           ('love', 'kanagaraj', 'film'): 2,
#           ('kanagaraj', 'film', 'ye'): 1,
#           ('film', 'ye', 'partial'): 1,
#           ('ye', 'partial', 'even'): 1,
#           ('partial', 'even', 'though'): 1,
#           ('even', 'though', 'film'): 1,
#           ('though', 'film', 'lot'): 1,
#           ('film', 'lot', 'easter'): 1,
#           ('lot', 'easter', 'egg'): 1,
#           ('easter', 'egg', 'subtl'): 1,
#           ('egg', 'subtl', 'dark'): 1,
#           ('subtl', 'dark', 'humour'): 1,
#           ('dark', 'humour', 'hint'): 1,
#           ('humour', 'hint', 'foreshadow'): 1,
#           ('hint', 'foreshadow', 'come'): 1,
#           ('foreshadow', 'come', 'event'): 1,
#           ('come', 'event', 'film'): 1,
#           ('event', 'film', 'anticlich'): 1,
#           ('film', 'anticlich', 'element'): 1,
#           ('anticlich', 'element', 'director'): 1,
#           ('element', 'director', 'success'): 1,
#           ('director', 'success', 'implement'): 1,
#           ('success', 'implement', 'movi'): 1,
#           ('implement', 'movi', 'seem'): 1,
#           ('movi', 'seem', 'lack'): 1,
#           ('seem', 'lack', 'logic'): 1,
#           ('lack', 'logic', 'place'): 1,
#           ('logic', 'place', 'scene'): 1,
#           ('place', 'scene', 'abrupt'): 1,
#           ('scene', 'abrupt', 'end'): 1,
#           ('abrupt', 'end', 'audienc'): 1,
#           ('end', 'audienc', 'agent'): 1,
#           ('audienc', 'agent', 'given'): 1,
#           ('agent', 'given', 'enough'): 1,
#           ('given', 'enough', 'time'): 1,
#           ('enough', 'time', 'take'): 1,
#           ('time', 'take', 'emot'): 1,
#           ('take', 'emot', 'second'): 1,
#           ('emot', 'second', 'halffor'): 1,
#           ('second', 'halffor', 'previou'): 1,
#           ('halffor', 'previou', 'film'): 1,
#           ('previou', 'film', 'love'): 1,
#           ('film', 'love', 'kanagaraj'): 1,
#           ('love', 'kanagaraj', 'didn'): 1,
#           ('kanagaraj', 'didn', 'issu'): 1,
#           ('didn', 'issu', 'conclus'): 1,
#           ('issu', 'conclus', 'movi'): 1,
#           ('conclus', 'movi', 'good'): 1,
#           ('movi', 'good', 'entertain'): 1,
#           ('good', 'entertain', 'lot'): 1,
#           ('entertain', 'lot', 'fun'): 1,
#           ('lot', 'fun', 'elementsdirect'): 1,
#           ('fun', 'elementsdirect', 'refer'): 1,
#           ('elementsdirect', 'refer', 'well'): 1,
#           ('refer', 'well', 'wait'): 1,
#           ('well', 'wait', 'good'): 1,
#           ('wait', 'good', 'script'): 1,
#           ('good', 'script', 'new'): 1,
#           ('script', 'new', 'dimens'): 1,
#           ('new', 'dimens', 'vital'): 1,
#           ('dimens', 'vital', 'vaathi'): 1,
#           ('vital', 'vaathi', 'singl'): 1,
#           ('vaathi', 'singl', 'hand'): 1,
#           ('singl', 'hand', 'reviv'): 1,
#           ('hand', 'reviv', 'postal'): 1,
#           ('reviv', 'postal', 'excit'): 1,
#           ('postal', 'excit', 'thalapathi'): 1,
#           ('excit', 'thalapathi', 'vital'): 1,
#           ('thalapathi', 'vital', 'vital'): 5,
#           ('vital', 'vital', 'setupathi'): 1,
#           ('vital', 'setupathi', 'show'): 1,
#           ('setupathi', 'show', 'complet'): 1,
#           ('show', 'complet', 'mass'): 1,
#           ('nasal', 'entertain', 'superb'): 1,
#           ('entertain', 'superb', 'by'): 1,
#           ('superb', 'by', 'love'): 1,
#           ('by', 'love', 'nail'): 1,
#           ('love', 'nail', 'worth'): 1,
#           ('nail', 'worth', 'watch'): 1,
#           ('worth', 'watch', 'thalapathi'): 1,
#           ('watch', 'thalapathi', 'vital'): 1,
#           ('thalapathi', 'vital', 'act'): 1,
#           ('vital', 'act', 'phenomenon'): 1,
#           ('act', 'phenomenon', 'frame'): 1,
#           ('phenomenon', 'frame', 'see'): 1,
#           ('frame', 'see', 'goosebumpsact'): 1,
#           ('see', 'goosebumpsact', 'comedyfight'): 1,
#           ('goosebumpsact', 'comedyfight', 'manner'): 1,
#           ('comedyfight', 'manner', 'word'): 1,
#           ('manner', 'word', 'mass'): 1,
#           ('word', 'mass', 'mass'): 1,
#           ('mass', 'mass', 'mass'): 1,
#           ('mass', 'mass', 'masssssssssin'): 1,
#           ('mass', 'masssssssssin', 'could'): 1,
#           ('masssssssssin', 'could', 'situat'): 1,
#           ('could', 'situat', 'collect'): 1,
#           ('situat', 'collect', 'box'): 1,
#           ('collect', 'box', 'offic'): 1,
#           ('box', 'offic', 'mind'): 1,
#           ('offic', 'mind', 'blow'): 1,
#           ('mind', 'blow', 'credit'): 1,
#           ('blow', 'credit', 'goe'): 1,
#           ('credit', 'goe', 'thalapathi'): 1,
#           ('goe', 'thalapathi', 'review'): 1,
#           ('thalapathi', 'review', 'posit'): 1,
#           ('review', 'posit', 'review'): 1,
#           ('posit', 'review', 'float'): 1,
#           ('review', 'float', 'world'): 1,
#           ('float', 'world', 'master'): 1,
#           ('world', 'master', 'became1st'): 1,
#           ('master', 'became1st', 'ever'): 1,
#           ('became1st', 'ever', 'blockbust'): 1,
#           ('ever', 'blockbust', 'film'): 1,
#           ('blockbust', 'film', '2021'): 1,
#           ('film', '2021', 'thalapathi'): 1,
#           ('2021', 'thalapathi', 'act'): 1,
#           ('thalapathi', 'act', 'extraordinari'): 1,
#           ('act', 'extraordinari', 'charm'): 1,
#           ('extraordinari', 'charm', 'vijaysethupathi'): 1,
#           ('charm', 'vijaysethupathi', 'havana'): 1,
#           ('vijaysethupathi', 'havana', 'steal'): 1,
#           ('havana', 'steal', 'show'): 1,
#           ('steal', 'show', 'one'): 1,
#           ('show', 'one', 'great'): 1,
#           ('one', 'great', 'vile'): 1,
#           ('great', 'vile', 'villain'): 1,
#           ('vile', 'villain', 'recent'): 1,
#           ('villain', 'recent', 'time'): 1,
#           ('recent', 'time', 'anirudh'): 1,
#           ('time', 'anirudh', 'by'): 1,
#           ('taken', 'hollywood', 'level'): 1,
#           ('hollywood', 'level', 'amaz'): 1,
#           ('level', 'amaz', 'musicsong'): 1,
#           ('amaz', 'musicsong', 'dirlokesh'): 1,
#           ('musicsong', 'dirlokesh', 'awesom'): 1,
#           ('dirlokesh', 'awesom', 'screenplay'): 1,
#           ('awesom', 'screenplay', 'direct'): 1,
#           ('screenplay', 'direct', 'make'): 1,
#           ('direct', 'make', 'u'): 1,
#           ('make', 'u', 'edg'): 1,
#           ('u', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'veryimport'): 1,
#           ('seat', 'veryimport', 'role'): 1,
#           ('veryimport', 'role', 'arjunda'): 1,
#           ('role', 'arjunda', 'fantast'): 1,
#           ('arjunda', 'fantast', 'thrill'): 1,
#           ('fantast', 'thrill', 'film'): 1,
#           ('thrill', 'film', 'verdict'): 1,
#           ('film', 'verdict', 'definit'): 1,
#           ('verdict', 'definit', 'huge'): 1,
#           ('definit', 'huge', 'blockbust'): 1,
#           ('huge', 'blockbust', 'master'): 1,
#           ('blockbust', 'master', 'master'): 1,
#           ('master', 'master', 'papa'): 1,
#           ('master', 'papa', 'mass'): 1,
#           ('papa', 'mass', 'blockbust'): 1,
#           ('mass', 'blockbust', 'd'): 1,
#           ('blockbust', 'd', 'v'): 1,
#           ('d', 'v', 'havana'): 2,
#           ('v', 'havana', 'kavalan'): 1,
#           ('havana', 'kavalan', 'thuppaki'): 1,
#           ('kavalan', 'thuppaki', 'vital'): 1,
#           ('thuppaki', 'vital', 'differ'): 1,
#           ('vital', 'differ', 'shade'): 2,
#           ('differ', 'shade', 'vital'): 1,
#           ('shade', 'vital', 'shown'): 1,
#           ('vital', 'shown', 'new'): 1,
#           ('shown', 'new', 'mannerismcool'): 1,
#           ('new', 'mannerismcool', 'swag'): 1,
#           ('mannerismcool', 'swag', 'vijaysethupathi'): 1,
#           ('swag', 'vijaysethupathi', 'score'): 1,
#           ('vijaysethupathi', 'score', 'traffic'): 1,
#           ('score', 'traffic', 'villain'): 1,
#           ('traffic', 'villain', 'act'): 1,
#           ('villain', 'act', 'love'): 1,
#           ('act', 'love', 'perfectli'): 1,
#           ('love', 'perfectli', 'balanc'): 1,
#           ('perfectli', 'balanc', 'script'): 1,
#           ('balanc', 'script', 'need'): 1,
#           ('script', 'need', 'multi'): 1,
#           ('need', 'multi', 'star'): 1,
#           ('multi', 'star', 'film'): 1,
#           ('star', 'film', 'postal'): 1,
#           ('film', 'postal', 'treat'): 1,
#           ('postal', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'onli'): 1,
#           ('everyon', 'onli', 'neg'): 1,
#           ('onli', 'neg', 'and'): 1,
#           ('neg', 'and', 'length'): 1,
#           ('and', 'length', 'scene'): 1,
#           ('length', 'scene', 'trim'): 1,
#           ('scene', 'trim', 'mean'): 1,
#           ('trim', 'mean', 'would'): 1,
#           ('mean', 'would', 'better'): 1,
#           ('would', 'better', 'lit'): 1,
#           ('better', 'lit', 'rage'): 1,
#           ('lit', 'rage', 'by'): 1,
#           ('rage', 'by', 'thalapathi'): 1,
#           ('by', 'thalapathi', 'makkalselvan'): 1,
#           ('thalapathi', 'makkalselvan', 'd'): 1,
#           ('makkalselvan', 'd', 'v'): 1,
#           ('v', 'havana', 'super'): 1,
#           ('havana', 'super', 'movi'): 1,
#           ('super', 'movi', 'visual'): 1,
#           ('movi', 'visual', 'effect'): 1,
#           ('visual', 'effect', 'movi'): 1,
#           ('effect', 'movi', 'by'): 1,
#           ('movi', 'by', 'sound'): 1,
#           ('by', 'sound', 'danc'): 1,
#           ('sound', 'danc', 'movement'): 1,
#           ('danc', 'movement', 'excel'): 1,
#           ('movement', 'excel', 'director'): 1,
#           ('excel', 'director', 'show'): 1,
#           ('director', 'show', 'differ'): 1,
#           ('show', 'differ', 'angl'): 1,
#           ('differ', 'angl', 'vital'): 1,
#           ('angl', 'vital', 'andvjiay'): 1,
#           ('vital', 'andvjiay', 'sethupathi'): 1,
#           ('andvjiay', 'sethupathi', 'cinephil'): 1,
#           ('sethupathi', 'cinephil', 'wait'): 1,
#           ('cinephil', 'wait', 'long'): 1,
#           ('wait', 'long', 'around'): 1,
#           ('long', 'around', '1'): 1,
#           ('around', '1', 'year'): 1,
#           ('1', 'year', 'wait'): 1,
#           ('year', 'wait', 'see'): 1,
#           ('wait', 'see', 'movi'): 1,
#           ('see', 'movi', 'big'): 1,
#           ('movi', 'big', 'screen'): 1,
#           ('big', 'screen', 'final'): 1,
#           ('screen', 'final', 'happen'): 1,
#           ('final', 'happen', 'master'): 1,
#           ('happen', 'master', 'film'): 1,
#           ('master', 'film', 'film'): 1,
#           ('film', 'film', 'pure'): 1,
#           ('film', 'pure', 'entertain'): 1,
#           ('pure', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'small'): 1,
#           ('movi', 'small', 'script'): 1,
#           ('small', 'script', 'execut'): 1,
#           ('script', 'execut', 'theatr'): 1,
#           ('execut', 'theatr', 'experi'): 1,
#           ('theatr', 'experi', 'good'): 1,
#           ('experi', 'good', 'mani'): 1,
#           ('good', 'mani', 'goosebump'): 1,
#           ('mani', 'goosebump', 'moment'): 1,
#           ('goosebump', 'moment', 'movi'): 1,
#           ('moment', 'movi', 'vital'): 1,
#           ('movi', 'vital', 'done'): 1,
#           ('vital', 'done', 'great'): 1,
#           ('done', 'great', 'act'): 1,
#           ('great', 'act', 'new'): 1,
#           ('act', 'new', 'manner'): 1,
#           ('new', 'manner', 'vital'): 1,
#           ('manner', 'vital', 'sethupathi'): 1,
#           ('vital', 'sethupathi', 'noth'): 1,
#           ('sethupathi', 'noth', 'say'): 1,
#           ('noth', 'say', 'pure'): 1,
#           ('say', 'pure', 'villain'): 1,
#           ('pure', 'villain', 'made'): 1,
#           ('villain', 'made', 'watch'): 1,
#           ('made', 'watch', 'till'): 1,
#           ('watch', 'till', 'go'): 1,
#           ('till', 'go', 'watch'): 1,
#           ...})

# %%
#Bio gram
from collections import Counter
bi_grams = nltk.bigrams(iterations)
fre_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# ('perfect', 'characterist', 'vital'):0.07142857142857142
# ('characterist', 'vital', 'v'):1.0
# ('vital', 'v', 'and'):0.007751937984496124
# ('v', 'and', 'half'):0.05714285714285714
# ('and', 'half', 'littl'):0.23076923076923078
# ('half', 'littl', 'bit'):0.09090909090909091
# ('littl', 'bit', 'lag'):0.14285714285714285
# ('bit', 'lag', 'without'):0.1111111111111111
# ('lag', 'without', 'stori'):0.5
# ('without', 'stori', 'moveexcept'):0.5
# ('stori', 'moveexcept', 've'):0.038461538461538464
# ('moveexcept', 've', 'manner'):1.0
# ('ve', 'manner', 'make'):0.1111111111111111
# ('manner', 'make', 'u'):0.1
# ('make', 'u', 'crazi'):0.05555555555555555
# ('u', 'crazi', 'also'):0.09090909090909091
# ('crazi', 'also', 'v'):0.3333333333333333
# ('also', 'v', 'terrorist'):0.07692307692307693
# ('v', 'terrorist', 'haunt'):0.02857142857142857
# ('terrorist', 'haunt', 'worth'):1.0
# ('haunt', 'worth', 'watch'):1.0
# ('worth', 'watch', 'like'):0.09090909090909091
# ('watch', 'like', 'thalapathi'):0.02040816326530612
# ('like', 'thalapathi', 'move'):0.05263157894736842
# ('thalapathi', 'move', 'vital'):0.0196078431372549
# ('move', 'vital', 'given'):0.07142857142857142
# ('vital', 'given', 'imag'):0.007751937984496124
# ('given', 'imag', 'allow'):0.25
# ('imag', 'allow', 'everyon'):1.0
# ('allow', 'everyon', 'mock'):0.5
# ('everyon', 'mock', 'sign'):0.16666666666666666
# ('mock', 'sign', 'helpless'):1.0
# ('sign', 'helpless', 'actorclimax'):1.0
# ('helpless', 'actorclimax', 'interv'):1.0
# ('actorclimax', 'interv', 'block'):1.0
# ('interv', 'block', 'terrificdont'):0.25
# ('block', 'terrificdont', 'listen'):1.0
# ('terrificdont', 'listen', 'neg'):1.0
# ('listen', 'neg', 'reviewsit'):0.3333333333333333
# ('neg', 'reviewsit', 'pure'):0.1111111111111111
# ('reviewsit', 'pure', 'commerci'):1.0
# ('pure', 'commerci', 'entertain'):0.16666666666666666
# ('commerci', 'entertain', 'decent'):0.14285714285714285
# ('entertain', 'decent', 'watchabl'):0.034482758620689655
# ('decent', 'watchabl', 'vital'):1.0
# ('watchabl', 'vital', 'v'):0.25
# ('vital', 'v', 'lift'):0.007751937984496124
# ('v', 'lift', 'whole'):0.02857142857142857
# ('lift', 'whole', 'movi'):0.5
# ('whole', 'movi', 'anirudh'):0.25
# ('movi', 'anirudh', 'by'):0.008264462809917356
# ('anirudh', 'by', 'taken'):0.14285714285714285
# ('by', 'taken', 'hollywood'):0.1
# ('taken', 'hollywood', 'cinema'):0.5
# ('hollywood', 'cinema', 'lokesh'):0.5
# ('cinema', 'lokesh', 'god'):0.25
# ('lokesh', 'god', 'screenplay'):0.5
# ('god', 'screenplay', 'direct'):0.5
# ('screenplay', 'direct', 'masterpiec'):0.07692307692307693
# ('direct', 'masterpiec', 'intermissionclimax'):0.08333333333333333
# ('masterpiec', 'intermissionclimax', '1sthalf'):0.3333333333333333
# ('intermissionclimax', '1sthalf', 'blockbuster2ndhalf'):1.0
# ('1sthalf', 'blockbuster2ndhalf', 'superhit'):1.0
# ('blockbuster2ndhalf', 'superhit', 'happi'):1.0
# ('superhit', 'happi', 'master'):1.0
# ('happi', 'master', 'postal'):1.0
# ('master', 'postal', 'anna'):0.023255813953488372
# ('postal', 'anna', 'joy'):0.14285714285714285
# ('anna', 'joy', 'theatr'):0.25
# ('joy', 'theatr', 'great'):1.0
# ('theatr', 'great', 'thing'):0.1
# ('great', 'thing', 'movi'):0.06666666666666667
# ('thing', 'movi', 'vital'):0.25
# ('movi', 'vital', 'v'):0.01652892561983471
# ('vital', 'v', 'vital'):0.015503875968992248
# ('v', 'vital', 'make'):0.02857142857142857
# ('vital', 'make', 'u'):0.007751937984496124
# ('make', 'u', 'go'):0.05555555555555555
# ('u', 'go', 'crazi'):0.09090909090909091
# ('go', 'crazi', 'actingmalavika'):0.125
# ('crazi', 'actingmalavika', 'andrew'):0.3333333333333333
# ('actingmalavika', 'andrew', 'good'):1.0
# ('andrew', 'good', 'jobarjun'):0.5
# ('good', 'jobarjun', 'da'):0.03225806451612903
# ('jobarjun', 'da', 'perfect'):1.0
# ('da', 'perfect', 'role'):0.16666666666666666
# ('perfect', 'role', 'good'):0.07142857142857142
# ('role', 'good', 'storylin'):0.06666666666666667
# ('good', 'storylin', 'averag'):0.03225806451612903
# ('storylin', 'averag', 'screenplay'):0.25
# ('averag', 'screenplay', 'director'):0.5
# ('screenplay', 'director', 'chosen'):0.07692307692307693
# ('director', 'chosen', 'deal'):0.07692307692307693
# ('chosen', 'deal', 'stori'):1.0
# ('deal', 'stori', 'nonlinear'):1.0
# ('stori', 'nonlinear', 'narrat'):0.038461538461538464
# ('nonlinear', 'narrat', 'suitabl'):1.0
# ('narrat', 'suitabl', 'stori'):0.5
# ('suitabl', 'stori', 'line'):1.0
# ('stori', 'line', 'want'):0.038461538461538464
# ('line', 'want', 'say'):0.14285714285714285
# ('want', 'say', 'want'):0.2
# ('say', 'want', 'say'):0.2
# ('want', 'say', 'storylin'):0.2
# ('say', 'storylin', 'say'):0.2
# ('storylin', 'say', 'one'):0.25
# ('say', 'one', 'line'):0.2
# ('one', 'line', 'actor'):0.05263157894736842
# ('line', 'actor', 'made'):0.14285714285714285
# ('actor', 'made', 'movi'):0.1111111111111111
# ('made', 'movi', 'interest'):0.1
# ('movi', 'interest', 'final'):0.008264462809917356
# ('interest', 'final', 'good'):0.25
# ('final', 'good', 'movi'):0.25
# ('good', 'movi', 'slow'):0.03225806451612903
# ('movi', 'slow', 'pace'):0.008264462809917356
# ('slow', 'pace', 'narrat'):0.25
# ('pace', 'narrat', 'one'):0.5
# ('narrat', 'one', 'time'):0.5
# ('one', 'time', 'watchabl'):0.05263157894736842
# ('time', 'watchabl', 'dont'):0.05
# ('watchabl', 'dont', 'miss'):0.25
# ('dont', 'miss', 'theatr'):0.125
# ('miss', 'theatr', 'experi'):0.14285714285714285
# ('theatr', 'experi', 'boy'):0.1
# ('experi', 'boy', 'movi'):0.16666666666666666
# ('boy', 'movi', 'make'):0.5
# ('movi', 'make', 'u'):0.008264462809917356
# ('make', 'u', 'celebr'):0.05555555555555555
# ('u', 'celebr', 'long'):0.09090909090909091
# ('celebr', 'long', 'time'):0.16666666666666666
# ('long', 'time', 'anaem'):0.1111111111111111
# ('time', 'anaem', 'vjvj'):0.05
# ('anaem', 'vjvj', 'mass'):1.0
# ('vjvj', 'mass', 'act'):1.0
# ('mass', 'act', 'st'):0.038461538461538464
# ('act', 'st', 'half'):0.03571428571428571
# ('st', 'half', 'vera'):0.25
# ('half', 'vera', 'mari'):0.045454545454545456
# ('vera', 'mari', 'vera'):0.1111111111111111
# ('mari', 'vera', 'mari'):0.5
# ('vera', 'mari', 'and'):0.1111111111111111
# ('mari', 'and', 'half'):0.5
# ('and', 'half', 'ok'):0.07692307692307693
# ('half', 'ok', 'superb'):0.045454545454545456
# ('ok', 'superb', 'untruth'):0.2
# ('superb', 'untruth', 'by'):0.125
# ('untruth', 'by', 'rock'):0.5
# ('by', 'rock', 'love'):0.05
# ('rock', 'love', 'direct'):0.2
# ('love', 'direct', 'differ'):0.02127659574468085
# ('direct', 'differ', 'thank'):0.08333333333333333
# ('differ', 'thank', 'u'):0.05
# ('thank', 'u', 'thalaivaa'):0.3333333333333333
# ('u', 'thalaivaa', 'enjoy'):0.09090909090909091
# ('thalaivaa', 'enjoy', 'movi'):1.0
# ('enjoy', 'movi', 'happi'):0.05263157894736842
# ('movi', 'happi', 'master'):0.008264462809917356
# ('master', 'postal', 'stori'):0.023255813953488372
# ('postal', 'stori', 'someth'):0.14285714285714285
# ('stori', 'someth', 'differ'):0.07692307692307693
# ('someth', 'differ', 'somewhat'):0.5
# ('differ', 'somewhat', 'hope'):0.1
# ('somewhat', 'hope', 'well'):1.0
# ('hope', 'well', 'made'):0.6666666666666666
# ('well', 'made', 'commerci'):0.1
# ('made', 'commerci', 'way'):0.2
# ('commerci', 'way', 'appeal'):0.2857142857142857
# ('way', 'appeal', 'fan'):0.3333333333333333
# ('appeal', 'fan', 'miss'):1.0
# ('fan', 'miss', 'theater'):0.06666666666666667
# ('miss', 'theater', 'found'):0.2857142857142857
# ('theater', 'found', 'better'):0.2857142857142857
# ('found', 'better', 'vila'):1.0
# ('better', 'vila', 'previou'):0.3333333333333333
# ('vila', 'previou', 'move'):0.125
# ('previou', 'move', 'like'):0.2857142857142857
# ('move', 'like', 'vigil'):0.14285714285714285
# ('like', 'vigil', 'makar'):0.10526315789473684
# ('vigil', 'makar', 'find'):1.0
# ('makar', 'find', 'love'):1.0
# ('find', 'love', 'touch'):1.0
# ('love', 'touch', 'film'):0.0425531914893617
# ('touch', 'film', 'may'):0.5
# ('film', 'may', 'like'):0.031746031746031744
# ('may', 'like', 'maanagaram'):0.6666666666666666
# ('like', 'maanagaram', 'faith'):0.10526315789473684
# ('maanagaram', 'faith', 'still'):0.6666666666666666
# ('faith', 'still', 'worth'):0.5
# ('still', 'worth', 'watch'):0.4
# ('worth', 'watch', 'movi'):0.2727272727272727
# ('watch', 'movi', 'stori'):0.061224489795918366
# ('movi', 'stori', 'direct'):0.01652892561983471
# ('stori', 'direct', 'perform'):0.07692307692307693
# ('direct', 'perform', 'vital'):0.16666666666666666
# ('perform', 'vital', 'v'):0.07407407407407407
# ('vital', 'v', 'everyon'):0.007751937984496124
# ('v', 'everyon', 'must'):0.02857142857142857
# ('everyon', 'must', 'watch'):0.16666666666666666
# ('must', 'watch', 'theater'):0.16666666666666666
# ('watch', 'theater', 'also'):0.02040816326530612
# ('theater', 'also', 'watch'):0.14285714285714285
# ('also', 'watch', 'month'):0.07692307692307693
# ('watch', 'month', 'to'):0.02040816326530612
# ('month', 'to', 'u'):0.5
# ('to', 'u', 'wont'):0.5
# ('u', 'wont', 'get'):0.09090909090909091
# ('wont', 'get', 'feel'):1.0
# ('get', 'feel', 'theater'):0.25
# ('feel', 'theater', 'movi'):0.25
# ('theater', 'movi', 'awesom'):0.14285714285714285
# ('movi', 'awesom', 'movi'):0.008264462809917356
# ('awesom', 'movi', 'vera'):0.07692307692307693
# ('movi', 'vera', 'level'):0.01652892561983471
# ('vera', 'level', 'big'):0.1111111111111111
# ('level', 'big', 'treat'):0.08333333333333333
# ('big', 'treat', 'thalapathi'):0.1111111111111111
# ('treat', 'thalapathi', 'fan'):0.14285714285714285
# ('thalapathi', 'fan', 'enjoy'):0.0196078431372549
# ('fan', 'enjoy', 'movi'):0.03333333333333333
# ('enjoy', 'movi', 'time'):0.05263157894736842
# ('movi', 'time', 'long'):0.008264462809917356
# ('time', 'long', 'gap'):0.05
# ('long', 'gap', 'enjoy'):0.1111111111111111
# ('gap', 'enjoy', 'everi'):1.0
# ('enjoy', 'everi', 'bit'):0.05263157894736842
# ('everi', 'bit', 'movi'):0.25
# ('bit', 'movi', 'super'):0.1111111111111111
# ('movi', 'super', 'movi'):0.01652892561983471
# ('super', 'movi', 'fan'):0.2
# ('movi', 'fan', 'enjoy'):0.008264462809917356
# ('fan', 'enjoy', 'fullfamili'):0.03333333333333333
# ('enjoy', 'fullfamili', 'audienc'):0.05263157894736842
# ('fullfamili', 'audienc', 'ku'):1.0
# ('audienc', 'ku', 'belaya'):0.125
# ('ku', 'belaya', 'enjoy'):1.0
# ('belaya', 'enjoy', 'irukum'):1.0
# ('enjoy', 'irukum', 'movi'):0.05263157894736842
# ('irukum', 'movi', 'thalapathi'):1.0
# ('movi', 'thalapathi', 'v'):0.008264462809917356
# ('thalapathi', 'v', 'vera'):0.0196078431372549
# ('v', 'vera', 'level'):0.02857142857142857
# ('vera', 'level', 'and'):0.1111111111111111
# ('level', 'and', 'by'):0.08333333333333333
# ('and', 'by', 'tharumaru'):0.07692307692307693
# ('by', 'tharumaru', 'loi'):0.05
# ('tharumaru', 'loi', 'posit'):1.0
# ('loi', 'posit', 'main'):0.3333333333333333
# ('posit', 'main', 'lead'):0.2
# ('main', 'lead', 'plot'):0.16666666666666666
# ('lead', 'plot', 'song'):0.2
# ('plot', 'song', 'n'):0.25
# ('song', 'n', 'by'):0.07692307692307693
# ('n', 'by', 'direct'):0.3333333333333333
# ('by', 'direct', 'neg'):0.05
# ('direct', 'neg', 'flat'):0.08333333333333333
# ('neg', 'flat', 'screenplay'):0.1111111111111111
# ('flat', 'screenplay', 'import'):1.0
# ('screenplay', 'import', 'femal'):0.07692307692307693
# ('import', 'femal', 'lead'):0.2
# ('femal', 'lead', '20'):1.0
# ('lead', '20', 'minut'):0.2
# ('20', 'minut', 'lengthi'):1.0
# ('minut', 'lengthi', 'twist'):0.3333333333333333
# ('lengthi', 'twist', 'turn'):0.5
# ('twist', 'turn', 'straight'):1.0
# ('turn', 'straight', 'movi'):1.0
# ('straight', 'movi', 'lot'):1.0
# ('movi', 'lot', 'mass'):0.008264462809917356
# ('lot', 'mass', 'content'):0.14285714285714285
# ('mass', 'content', 'actor'):0.038461538461538464
# ('content', 'actor', 'play'):1.0
# ('actor', 'play', 'role'):0.1111111111111111
# ('play', 'role', 'well'):0.0625
# ('role', 'well', 'vital'):0.06666666666666667
# ('well', 'vital', 'cool'):0.05
# ('vital', 'cool', 'teacher'):0.007751937984496124
# ('cool', 'teacher', 'vital'):0.3333333333333333
# ('teacher', 'vital', 'sethupathi'):1.0
# ('vital', 'sethupathi', 'terrifi'):0.007751937984496124
# ('sethupathi', 'terrifi', 'villain'):0.030303030303030304
# ('terrifi', 'villain', 'expect'):1.0
# ('villain', 'expect', 'love'):0.05555555555555555
# ('expect', 'love', 'kanagaraj'):0.2
# ('love', 'kanagaraj', 'movi'):0.0425531914893617
# ('kanagaraj', 'movi', 'ok'):0.1111111111111111
# ('movi', 'ok', 'movi'):0.008264462809917356
# ('ok', 'movi', 'antrum'):0.2
# ('movi', 'antrum', 'music'):0.008264462809917356
# ('antrum', 'music', 'pu'):1.0
# ('music', 'pu', 'magnum'):0.07692307692307693
# ('pu', 'magnum', 'overal'):1.0
# ('magnum', 'overal', 'good'):1.0
# ('overal', 'good', 'fan'):0.07142857142857142
# ('good', 'fan', 'ordinari'):0.03225806451612903
# ('fan', 'ordinari', 'fan'):0.03333333333333333
# ('ordinari', 'fan', 'ok'):0.5
# ('fan', 'ok', 'sure'):0.03333333333333333
# ('ok', 'sure', 'watchabl'):0.2
# ('sure', 'watchabl', 'love'):0.125
# ('watchabl', 'love', 'way'):0.25
# ('love', 'way', 'd'):0.02127659574468085
# ('way', 'd', 'live'):0.16666666666666666
# ('d', 'live', 'move'):0.125
# ('live', 'move', 'stori'):0.3333333333333333
# ('move', 'stori', 'line'):0.07142857142857142
# ('stori', 'line', 'evil'):0.038461538461538464
# ('line', 'evil', 'havana'):0.14285714285714285
# ('evil', 'havana', 'realli'):0.25
# ('havana', 'realli', 'masterpiec'):0.07142857142857142
# ('realli', 'masterpiec', 'master'):0.1
# ('masterpiec', 'master', 'team'):0.3333333333333333
# ('master', 'team', 'everyon'):0.023255813953488372
# ('team', 'everyon', 'job'):0.5
# ('everyon', 'job', 'well'):0.16666666666666666
# ('job', 'well', 'final'):0.2
# ('well', 'final', 'celebr'):0.05
# ('final', 'celebr', 'master'):0.25
# ('celebr', 'master', 'brilliant'):0.16666666666666666
# ('master', 'brilliant', 'exampl'):0.023255813953488372
# ('brilliant', 'exampl', 'perfect'):0.16666666666666666
# ('exampl', 'perfect', 'cat'):0.5
# ('perfect', 'cat', 'mous'):0.07142857142857142
# ('cat', 'mous', 'actionthril'):1.0
# ('mous', 'actionthril', 'director'):1.0
# ('actionthril', 'director', 'love'):1.0
# ('director', 'love', 'gave'):0.07692307692307693
# ('love', 'gave', 'u'):0.02127659574468085
# ('gave', 'u', 'promis'):0.5
# ('u', 'promis', 'master'):0.09090909090909091
# ('promis', 'master', 'break'):0.5
# ('master', 'break', 'cliché'):0.023255813953488372
# ('break', 'cliché', 'typic'):1.0
# ('cliché', 'typic', 'thalapathi'):0.5
# ('typic', 'thalapathi', 'movi'):0.3333333333333333
# ('thalapathi', 'movi', 'usual'):0.0196078431372549
# ('movi', 'usual', 'kept'):0.008264462809917356
# ('usual', 'kept', 'promis'):0.2
# ('kept', 'promis', 'master'):0.5
# ('promis', 'master', 'clash'):0.5
# ('master', 'clash', 'protagonist'):0.023255813953488372
# ('clash', 'protagonist', 'antagonist'):0.3333333333333333
# ('protagonist', 'antagonist', 'isn'):0.25
# ('antagonist', 'isn', 'usual'):0.14285714285714285
# ('isn', 'usual', 'clash'):1.0
# ('usual', 'clash', 'see'):0.2
# ('clash', 'see', 'mani'):0.3333333333333333
# ('see', 'mani', 'tail'):0.1111111111111111
# ('mani', 'tail', 'move'):0.2
# ('tail', 'move', 'stori'):0.25
# ('move', 'stori', 'differ'):0.07142857142857142
# ('stori', 'differ', 'love'):0.038461538461538464
# ('differ', 'love', 'written'):0.05
# ('love', 'written', 'charact'):0.02127659574468085
# ('written', 'charact', 'antagonist'):0.5
# ('charact', 'antagonist', 'havana'):0.05
# ('antagonist', 'havana', 'amount'):0.14285714285714285
# ('havana', 'amount', 'brillianc'):0.07142857142857142
# ('amount', 'brillianc', 'power'):0.5
# ('brillianc', 'power', 'protagonist'):1.0
# ('power', 'protagonist', 'd'):0.25
# ('protagonist', 'd', 'vital'):0.25
# ('d', 'vital', 'sethupathi'):0.125
# ('vital', 'sethupathi', 'fail'):0.007751937984496124
# ('sethupathi', 'fail', 'role'):0.030303030303030304
# ('fail', 'role', 'devilish'):0.5
# ('role', 'devilish', 'antagonist'):0.06666666666666667
# ('devilish', 'antagonist', 'whenev'):1.0
# ('antagonist', 'whenev', 'appear'):0.14285714285714285
# ('whenev', 'appear', 'screen'):1.0
# ('appear', 'screen', 'blast'):1.0
# ('screen', 'blast', 'manner'):0.058823529411764705
# ('blast', 'manner', 'dialogu'):0.5
# ('manner', 'dialogu', 'deliveri'):0.1
# ('dialogu', 'deliveri', 'emot'):0.25
# ('deliveri', 'emot', 'deliv'):1.0
# ('emot', 'deliv', 'charact'):0.16666666666666666
# ('deliv', 'charact', 'spoon'):0.5
# ('charact', 'spoon', 'last'):0.05
# ('spoon', 'last', 'least'):1.0
# ('last', 'least', 'thalapathi'):0.5
# ('least', 'thalapathi', 'prove'):1.0
# ('thalapathi', 'prove', 'prowess'):0.0196078431372549
# ('prove', 'prowess', 'excel'):0.25
# ('prowess', 'excel', 'actor'):1.0
# ('excel', 'actor', 'fanci'):0.2
# ('actor', 'fanci', 'insid'):0.1111111111111111
# ('fanci', 'insid', 'rejoic'):1.0
# ('insid', 'rejoic', 'broke'):1.0
# ('rejoic', 'broke', 'cliché'):1.0
# ('broke', 'cliché', 'dialogu'):0.5
# ('cliché', 'dialogu', 'fight'):0.5
# ('dialogu', 'fight', 'express'):0.25
# ('fight', 'express', 'charact'):0.08333333333333333
# ('express', 'charact', 'd'):1.0
# ('charact', 'd', 'uniqu'):0.05
# ('d', 'uniqu', 'broke'):0.125
# ('uniqu', 'broke', 'stereotyp'):0.16666666666666666
# ('broke', 'stereotyp', 'ador'):0.5
# ('stereotyp', 'ador', 'everi'):1.0
# ('ador', 'everi', 'moment'):1.0
# ('everi', 'moment', 'live'):0.25
# ('moment', 'live', 'john'):0.14285714285714285
# ('live', 'john', 'durairaj'):0.3333333333333333
# ('john', 'durairaj', 'screen'):0.3333333333333333
# ('durairaj', 'screen', 'technic'):1.0
# ('screen', 'technic', 'crew'):0.058823529411764705
# ('technic', 'crew', 'master'):1.0
# ('crew', 'master', 'deserv'):1.0
# ('master', 'deserv', 'stand'):0.023255813953488372
# ('deserv', 'stand', 'orat'):0.5
# ('stand', 'orat', 'extraordinari'):1.0
# ('orat', 'extraordinari', 'work'):1.0
# ('extraordinari', 'work', 'they'):0.5
# ('work', 'they', 'done'):0.125
# ('they', 'done', 'background'):1.0
# ('done', 'background', 'score'):0.1111111111111111
# ('background', 'score', 'master'):0.1
# ('score', 'master', 'one'):0.1111111111111111
# ('master', 'one', 'best'):0.023255813953488372
# ('one', 'best', 'composit'):0.05263157894736842
# ('best', 'composit', 'anirudh'):0.038461538461538464
# ('composit', 'anirudh', 'career'):1.0
# ('anirudh', 'career', 'second'):0.07142857142857142
# ('career', 'second', 'protagonist'):0.25
# ('second', 'protagonist', 'movi'):0.16666666666666666
# ('protagonist', 'movi', 'satan'):0.25
# ('movi', 'satan', 'sooriyan'):0.008264462809917356
# ('satan', 'sooriyan', 'visual'):1.0
# ('sooriyan', 'visual', 'anoth'):1.0
# ('visual', 'anoth', 'highlight'):0.3333333333333333
# ('anoth', 'highlight', 'cinematographi'):0.14285714285714285
# ('highlight', 'cinematographi', 'topnotch'):0.5
# ('cinematographi', 'topnotch', 'uniqu'):0.5
# ('topnotch', 'uniqu', 'special'):1.0
# ('uniqu', 'special', 'prais'):0.16666666666666666
# ('special', 'prais', 'stung'):0.5
# ('prais', 'stung', 'master'):1.0
# ('stung', 'master', 'sila'):0.3333333333333333
# ('master', 'sila', 'give'):0.023255813953488372
# ('sila', 'give', 'u'):1.0
# ('give', 'u', 'class'):0.1111111111111111
# ('u', 'class', 'realist'):0.09090909090909091
# ('class', 'realist', 'action'):0.3333333333333333
# ('realist', 'action', 'sequenc'):0.5
# ('action', 'sequenc', 'action'):0.05263157894736842
# ('sequenc', 'action', 'scene'):0.14285714285714285
# ('action', 'scene', 'sound'):0.05263157894736842
# ('scene', 'sound', 'master'):0.05
# ('sound', 'master', 'amaz'):0.3333333333333333
# ('master', 'amaz', 'thuppakki'):0.023255813953488372
# ('amaz', 'thuppakki', 'that'):0.14285714285714285
# ('thuppakki', 'that', 'big'):0.5
# ('that', 'big', 'statement'):0.5
# ('big', 'statement', 'overal'):0.1111111111111111
# ('statement', 'overal', 'master'):1.0
# ('overal', 'master', '50'):0.07142857142857142
# ('master', '50', 'love'):0.023255813953488372
# ('50', 'love', 'film'):0.4
# ('love', 'film', '50'):0.02127659574468085
# ('film', '50', 'thalapathi'):0.015873015873015872
# ('50', 'thalapathi', 'vila'):0.2
# ('thalapathi', 'vila', 'film'):0.0196078431372549
# ('vila', 'film', 'dont'):0.125
# ('film', 'dont', 'think'):0.015873015873015872
# ('dont', 'think', 'anyon'):0.125
# ('think', 'anyon', 'would'):0.3333333333333333
# ('anyon', 'would', 'hate'):1.0
# ('would', 'hate', 'movi'):0.1111111111111111
# ('hate', 'movi', 'best'):0.5
# ('movi', 'best', 'blend'):0.008264462809917356
# ('best', 'blend', 'mass'):0.038461538461538464
# ('blend', 'mass', 'class'):1.0
# ('mass', 'class', 'movi'):0.038461538461538464
# ('class', 'movi', 'complet'):0.3333333333333333
# ('movi', 'complet', 'mass'):0.008264462809917356
# ('complet', 'mass', 'nasal'):0.5
# ('mass', 'nasal', 'entertain'):0.11538461538461539
# ('nasal', 'entertain', 'long'):0.3333333333333333
# ('entertain', 'long', 'time'):0.034482758620689655
# ('long', 'time', 'indian'):0.1111111111111111
# ('time', 'indian', 'cinema'):0.05
# ('indian', 'cinema', 'industri'):0.3333333333333333
# ('cinema', 'industri', 'got'):0.25
# ('industri', 'got', 'wonder'):0.5
# ('got', 'wonder', 'movi'):0.5
# ('wonder', 'movi', 'worth'):0.25
# ('movi', 'worth', 'watch'):0.01652892561983471
# ('worth', 'watch', 'nice'):0.18181818181818182
# ('watch', 'nice', 'movi'):0.02040816326530612
# ('nice', 'movi', 'worth'):0.14285714285714285
# ('watch', 'nice', 'act'):0.02040816326530612
# ('nice', 'act', 'good'):0.14285714285714285
# ('act', 'good', 'direct'):0.03571428571428571
# ('good', 'direct', 'best'):0.03225806451612903
# ('direct', 'best', 'action'):0.08333333333333333
# ('best', 'action', 'scene'):0.038461538461538464
# ('action', 'scene', 'first'):0.05263157894736842
# ('scene', 'first', 'refresh'):0.05
# ('first', 'refresh', 'see'):0.06666666666666667
# ('refresh', 'see', 'vital'):1.0
# ('see', 'vital', 'tri'):0.1111111111111111
# ('vital', 'tri', 'someth'):0.007751937984496124
# ('tri', 'someth', 'differ'):0.5
# ('someth', 'differ', 'movi'):0.25
# ('differ', 'movi', 'mass'):0.05
# ('movi', 'mass', 'element'):0.008264462809917356
# ('mass', 'element', 'emot'):0.038461538461538464
# ('element', 'emot', 'littl'):0.2
# ('emot', 'littl', 'bit'):0.16666666666666666
# ('littl', 'bit', 'top'):0.14285714285714285
# ('bit', 'top', 'action'):0.1111111111111111
# ('top', 'action', 'there'):0.3333333333333333
# ('action', 'there', 'uniqu'):0.05263157894736842
# ('there', 'uniqu', 'element'):0.16666666666666666
# ('uniqu', 'element', 'even'):0.16666666666666666
# ('element', 'even', 'vital'):0.2
# ('even', 'vital', 'look'):0.16666666666666666
# ('vital', 'look', 'total'):0.007751937984496124
# ('look', 'total', 'differ'):0.2
# ('total', 'differ', 'person'):0.16666666666666666
# ('differ', 'person', 'embodi'):0.05
# ('person', 'embodi', 'charact'):0.16666666666666666
# ('embodi', 'charact', 'didn'):1.0
# ('charact', 'didn', 'like'):0.05
# ('didn', 'like', 'abl'):0.2
# ('like', 'abl', 'move'):0.05263157894736842
# ('abl', 'move', 'sure'):0.5
# ('move', 'sure', 'entertain'):0.07142857142857142
# ('sure', 'entertain', 'patch'):0.125
# ('entertain', 'patch', 'great'):0.034482758620689655
# ('patch', 'great', 'allmast'):1.0
# ('great', 'allmast', 'contrari'):0.06666666666666667
# ('allmast', 'contrari', 'might'):1.0
# ('contrari', 'might', 'celebr'):1.0
# ('might', 'celebr', 'move'):0.3333333333333333
# ('celebr', 'move', 'time'):0.16666666666666666
# ('move', 'time', 'fan'):0.07142857142857142
# ('time', 'fan', 'appreci'):0.05
# ('fan', 'appreci', 'harsh'):0.03333333333333333
# ('appreci', 'harsh', 'realiti'):0.25
# ('harsh', 'realiti', 'showcas'):1.0
# ('realiti', 'showcas', 'life'):0.5
# ('showcas', 'life', 'age'):0.5
# ('life', 'age', 'peopl'):0.3333333333333333
# ('age', 'peopl', 'crime'):1.0
# ('peopl', 'crime', 'exploit'):0.14285714285714285
# ('crime', 'exploit', 'thing'):1.0
# ('exploit', 'thing', 'peopl'):1.0
# ('thing', 'peopl', 'influenc'):0.25
# ('peopl', 'influenc', 'life'):0.14285714285714285
# ('influenc', 'life', 'overal'):1.0
# ('life', 'overal', 'great'):0.3333333333333333
# ('overal', 'great', 'watch'):0.07142857142857142
# ('great', 'watch', 'mani'):0.06666666666666667
# ('watch', 'mani', 'might'):0.02040816326530612
# ('mani', 'might', 'like'):0.2
# ('might', 'like', 'perfect'):0.3333333333333333
# ('like', 'perfect', 'time'):0.05263157894736842
# ('perfect', 'time', 'till'):0.07142857142857142
# ('time', 'till', 'get'):0.05
# ('till', 'get', 'recognit'):0.25
# ('get', 'recognit', 'deserv'):0.25
# ('recognit', 'deserv', 'one'):1.0
# ('deserv', 'one', 'thing'):0.5
# ('one', 'thing', 'vital'):0.05263157894736842
# ('thing', 'vital', 'sethubathi'):0.25
# ('vital', 'sethubathi', 'fantast'):0.007751937984496124
# ('sethubathi', 'fantast', 'realli'):1.0
# ('fantast', 'realli', 'good'):0.2
# ('realli', 'good', 'soviet'):0.1
# ('good', 'soviet', 'emot'):0.03225806451612903
# ('soviet', 'emot', 'action'):1.0
# ('emot', 'action', 'also'):0.16666666666666666
# ('action', 'also', 'littl'):0.05263157894736842
# ('also', 'littl', 'bit'):0.07692307692307693
# ('littl', 'bit', 'love'):0.14285714285714285
# ('bit', 'love', 'stori'):0.1111111111111111
# ('love', 'stori', 'hatsoff'):0.02127659574468085
# ('stori', 'hatsoff', 'effort'):0.038461538461538464
# ('hatsoff', 'effort', 'vila'):1.0
# ('effort', 'vila', 'never'):1.0
# ('vila', 'never', 'seen'):0.0625
# ('never', 'seen', 'perform'):0.25
# ('seen', 'perform', 'side'):0.2
# ('perform', 'side', 'anirith'):0.037037037037037035
# ('side', 'anirith', 'good'):0.3333333333333333
# ('anirith', 'good', 'job'):1.0
# ('good', 'job', 'stori'):0.03225806451612903
# ('job', 'stori', 'part'):0.2
# ('stori', 'part', 'mass'):0.038461538461538464
# ('part', 'mass', 'scene'):0.14285714285714285
# ('mass', 'scene', 'screenplay'):0.038461538461538464
# ('scene', 'screenplay', 'worst'):0.05
# ('screenplay', 'worst', 'part'):0.07692307692307693
# ('worst', 'part', 'movi'):1.0
# ('part', 'movi', 'even'):0.14285714285714285
# ('movi', 'even', 'mani'):0.008264462809917356
# ('even', 'mani', 'charact'):0.16666666666666666
# ('mani', 'charact', 'nobodi'):0.2
# ('charact', 'nobodi', 'charact'):0.05
# ('nobodi', 'charact', 'develop'):1.0
# ('charact', 'develop', 'well'):0.05
# ('develop', 'well', 'stori'):1.0
# ('well', 'stori', 'line'):0.05
# ('stori', 'line', 'track'):0.038461538461538464
# ('line', 'track', 'everybodi'):0.14285714285714285
# ('track', 'everybodi', 'come'):1.0
# ('everybodi', 'come', 'mass'):1.0
# ('come', 'mass', 'element'):0.125
# ('mass', 'element', 'stori'):0.038461538461538464
# ('element', 'stori', 'line'):0.2
# ('stori', 'line', 'movi'):0.038461538461538464
# ('line', 'movi', 'celebr'):0.14285714285714285
# ('movi', 'celebr', 'fan'):0.008264462809917356
# ('celebr', 'fan', 'vila'):0.16666666666666666
# ('fan', 'vila', 'manual'):0.03333333333333333
# ('vila', 'manual', 'sylvan'):0.0625
# ('manual', 'sylvan', 'attitud'):0.3333333333333333
# ('sylvan', 'attitud', 'superb'):0.3333333333333333
# ('attitud', 'superb', 'thalapathi'):0.2
# ('superb', 'thalapathi', 'mass'):0.125
# ('thalapathi', 'mass', 'e'):0.0196078431372549
# ('mass', 'e', 'entertain'):0.038461538461538464
# ('e', 'entertain', 'r'):0.3333333333333333
# ('entertain', 'r', 'record'):0.034482758620689655
# ('r', 'record', 'wast'):1.0
# ('record', 'wast', 'money'):1.0
# ('wast', 'money', 'timew'):1.0
# ('money', 'timew', 'ff'):1.0
# ('timew', 'ff', 'shout'):1.0
# ('ff', 'shout', 'worth'):1.0
# ('shout', 'worth', 'allow'):1.0
# ('worth', 'allow', 'hope'):0.09090909090909091
# ('allow', 'hope', 'rate'):0.5
# ('hope', 'rate', 'movienot'):0.3333333333333333
# ('rate', 'movienot', 'love'):0.125
# ('movienot', 'love', 'movi'):1.0
# ('love', 'movi', 'one'):0.02127659574468085
# ('movi', 'one', 'await'):0.008264462809917356
# ('one', 'await', 'anticip'):0.05263157894736842
# ('await', 'anticip', 'movi'):1.0
# ('anticip', 'movi', 'past'):1.0
# ('movi', 'past', 'two'):0.008264462809917356
# ('past', 'two', 'year'):1.0
# ('two', 'year', 'master'):0.2
# ('year', 'master', 'hit'):0.16666666666666666
# ('master', 'hit', 'screen'):0.023255813953488372
# ('hit', 'screen', 'lead'):0.5
# ('screen', 'lead', 'role'):0.058823529411764705
# ('lead', 'role', 'play'):0.2
# ('role', 'play', 'protagonist'):0.06666666666666667
# ('play', 'protagonist', 'thalapathi'):0.0625
# ('protagonist', 'thalapathi', 'vital'):0.25
# ('thalapathi', 'vital', 'antagonist'):0.0196078431372549
# ('vital', 'antagonist', 'manual'):0.007751937984496124
# ('antagonist', 'manual', 'sylvan'):0.14285714285714285
# ('manual', 'sylvan', 'vital'):0.6666666666666666
# ('sylvan', 'vital', 'sethupathi'):0.3333333333333333
# ('vital', 'sethupathi', 'although'):0.007751937984496124
# ('sethupathi', 'although', 'film'):0.030303030303030304
# ('although', 'film', 'clash'):1.0
# ('film', 'clash', 'two'):0.015873015873015872
# ('clash', 'two', 'vital'):0.3333333333333333
# ('two', 'vital', 'lot'):0.2
# ('vital', 'lot', 'charact'):0.007751937984496124
# ('lot', 'charact', 'act'):0.14285714285714285
# ('charact', 'act', 'role'):0.05
# ('act', 'role', 'well'):0.03571428571428571
# ('role', 'well', 'plotwis'):0.06666666666666667
# ('well', 'plotwis', 'firsthalf'):0.05
# ('plotwis', 'firsthalf', 'play'):1.0
# ('firsthalf', 'play', 'import'):1.0
# ('play', 'import', 'part'):0.0625
# ('import', 'part', 'establish'):0.2
# ('part', 'establish', 'charact'):0.14285714285714285
# ('establish', 'charact', 'maintain'):0.5
# ('charact', 'maintain', 'pace'):0.05
# ('maintain', 'pace', 'keep'):1.0
# ('pace', 'keep', 'audienc'):0.5
# ('keep', 'audienc', 'entertain'):0.25
# ('audienc', 'entertain', 'john'):0.125
# ('entertain', 'john', 'dhurairaj'):0.034482758620689655
# ('john', 'dhurairaj', 'vijayquirki'):0.3333333333333333
# ('dhurairaj', 'vijayquirki', 'funni'):1.0
# ('vijayquirki', 'funni', 'charact'):1.0
# ('funni', 'charact', 'vila'):1.0
# ('charact', 'vila', 'overal'):0.05
# ('vila', 'overal', 'outstand'):0.0625
# ('overal', 'outstand', 'screenpres'):0.07142857142857142
# ('outstand', 'screenpres', 'second'):0.3333333333333333
# ('screenpres', 'second', 'half'):1.0
# ('second', 'half', 'speed'):0.16666666666666666
# ('half', 'speed', 'stick'):0.045454545454545456
# ('speed', 'stick', 'plot'):1.0
# ('stick', 'plot', 'keep'):1.0
# ('plot', 'keep', 'humour'):0.25
# ('keep', 'humour', 'bundl'):0.25
# ('humour', 'bundl', 'within'):0.5
# ('bundl', 'within', 'stori'):1.0
# ('within', 'stori', 'elev'):1.0
# ('stori', 'elev', 'interv'):0.038461538461538464
# ('elev', 'interv', 'good'):0.3333333333333333
# ('interv', 'good', 'addit'):0.25
# ('good', 'addit', 'film'):0.03225806451612903
# ('addit', 'film', 'anirudh'):1.0
# ('film', 'anirudh', 'gift'):0.015873015873015872
# ('anirudh', 'gift', 'industri'):0.07142857142857142
# ('gift', 'industri', 'background'):1.0
# ('industri', 'background', 'score'):0.5
# ('background', 'score', 'elev'):0.1
# ('score', 'elev', 'scene'):0.1111111111111111
# ('elev', 'scene', 'give'):0.3333333333333333
# ('scene', 'give', 'audienc'):0.05
# ('give', 'audienc', 'twice'):0.1111111111111111
# ('audienc', 'twice', 'amount'):0.125
# ('twice', 'amount', 'impact'):1.0
# ('amount', 'impact', 'scene'):0.5
# ('impact', 'scene', 'song'):1.0
# ('scene', 'song', 'film'):0.05
# ('song', 'film', 'use'):0.07692307692307693
# ('film', 'use', 'background'):0.015873015873015872
# ('use', 'background', 'speak'):0.16666666666666666
# ('background', 'speak', 'song'):0.1
# ('speak', 'song', 'seem'):1.0
# ('song', 'seem', 'lack'):0.07692307692307693
# ('seem', 'lack', 'better'):0.3333333333333333
# ('lack', 'better', 'placement'):0.2
# ('better', 'placement', 'induc'):0.16666666666666666
# ('placement', 'induc', 'littl'):1.0
# ('induc', 'littl', 'law'):1.0
# ('littl', 'law', 'film'):0.14285714285714285
# ('law', 'film', 'main'):0.5
# ('film', 'main', 'question'):0.015873015873015872
# ('main', 'question', 'love'):0.16666666666666666
# ('question', 'love', 'kanagaraj'):1.0
# ('love', 'kanagaraj', 'film'):0.0425531914893617
# ('kanagaraj', 'film', 'ye'):0.1111111111111111
# ('film', 'ye', 'partial'):0.015873015873015872
# ('ye', 'partial', 'even'):0.25
# ('partial', 'even', 'though'):1.0
# ('even', 'though', 'film'):0.16666666666666666
# ('though', 'film', 'lot'):1.0
# ('film', 'lot', 'easter'):0.015873015873015872
# ('lot', 'easter', 'egg'):0.14285714285714285
# ('easter', 'egg', 'subtl'):1.0
# ('egg', 'subtl', 'dark'):1.0
# ('subtl', 'dark', 'humour'):1.0
# ('dark', 'humour', 'hint'):1.0
# ('humour', 'hint', 'foreshadow'):0.5
# ('hint', 'foreshadow', 'come'):1.0
# ('foreshadow', 'come', 'event'):1.0
# ('come', 'event', 'film'):0.125
# ('event', 'film', 'anticlich'):1.0
# ('film', 'anticlich', 'element'):0.015873015873015872
# ('anticlich', 'element', 'director'):1.0
# ('element', 'director', 'success'):0.2
# ('director', 'success', 'implement'):0.07692307692307693
# ('success', 'implement', 'movi'):1.0
# ('implement', 'movi', 'seem'):1.0
# ('movi', 'seem', 'lack'):0.008264462809917356
# ('seem', 'lack', 'logic'):0.3333333333333333
# ('lack', 'logic', 'place'):0.2
# ('logic', 'place', 'scene'):0.3333333333333333
# ('place', 'scene', 'abrupt'):0.25
# ('scene', 'abrupt', 'end'):0.05
# ('abrupt', 'end', 'audienc'):1.0
# ('end', 'audienc', 'agent'):0.3333333333333333
# ('audienc', 'agent', 'given'):0.125
# ('agent', 'given', 'enough'):1.0
# ('given', 'enough', 'time'):0.25
# ('enough', 'time', 'take'):1.0
# ('time', 'take', 'emot'):0.05
# ('take', 'emot', 'second'):0.25
# ('emot', 'second', 'halffor'):0.16666666666666666
# ('second', 'halffor', 'previou'):0.16666666666666666
# ('halffor', 'previou', 'film'):1.0
# ('previou', 'film', 'love'):0.14285714285714285
# ('film', 'love', 'kanagaraj'):0.015873015873015872
# ('love', 'kanagaraj', 'didn'):0.02127659574468085
# ('kanagaraj', 'didn', 'issu'):0.1111111111111111
# ('didn', 'issu', 'conclus'):0.2
# ('issu', 'conclus', 'movi'):0.5
# ('conclus', 'movi', 'good'):1.0
# ('movi', 'good', 'entertain'):0.008264462809917356
# ('good', 'entertain', 'lot'):0.03225806451612903
# ('entertain', 'lot', 'fun'):0.034482758620689655
# ('lot', 'fun', 'elementsdirect'):0.14285714285714285
# ('fun', 'elementsdirect', 'refer'):0.5
# ('elementsdirect', 'refer', 'well'):1.0
# ('refer', 'well', 'wait'):1.0
# ('well', 'wait', 'good'):0.05
# ('wait', 'good', 'script'):0.3333333333333333
# ('good', 'script', 'new'):0.03225806451612903
# ('script', 'new', 'dimens'):0.25
# ('new', 'dimens', 'vital'):0.125
# ('dimens', 'vital', 'vaathi'):1.0
# ('vital', 'vaathi', 'singl'):0.007751937984496124
# ('vaathi', 'singl', 'hand'):0.16666666666666666
# ('singl', 'hand', 'reviv'):1.0
# ('hand', 'reviv', 'postal'):0.5
# ('reviv', 'postal', 'excit'):1.0
# ('postal', 'excit', 'thalapathi'):0.14285714285714285
# ('excit', 'thalapathi', 'vital'):0.5
# ('thalapathi', 'vital', 'vital'):0.09803921568627451
# ('vital', 'vital', 'setupathi'):0.007751937984496124
# ('vital', 'setupathi', 'show'):0.007751937984496124
# ('setupathi', 'show', 'complet'):0.5
# ('show', 'complet', 'mass'):0.1
# ('nasal', 'entertain', 'superb'):0.3333333333333333
# ('entertain', 'superb', 'by'):0.034482758620689655
# ('superb', 'by', 'love'):0.125
# ('by', 'love', 'nail'):0.05
# ('love', 'nail', 'worth'):0.02127659574468085
# ('nail', 'worth', 'watch'):0.5
# ('worth', 'watch', 'thalapathi'):0.09090909090909091
# ('watch', 'thalapathi', 'vital'):0.02040816326530612
# ('thalapathi', 'vital', 'act'):0.0196078431372549
# ('vital', 'act', 'phenomenon'):0.007751937984496124
# ('act', 'phenomenon', 'frame'):0.03571428571428571
# ('phenomenon', 'frame', 'see'):0.3333333333333333
# ('frame', 'see', 'goosebumpsact'):1.0
# ('see', 'goosebumpsact', 'comedyfight'):0.1111111111111111
# ('goosebumpsact', 'comedyfight', 'manner'):1.0
# ('comedyfight', 'manner', 'word'):1.0
# ('manner', 'word', 'mass'):0.1
# ('word', 'mass', 'mass'):0.5
# ('mass', 'mass', 'mass'):0.038461538461538464
# ('mass', 'mass', 'masssssssssin'):0.038461538461538464
# ('mass', 'masssssssssin', 'could'):0.038461538461538464
# ('masssssssssin', 'could', 'situat'):1.0
# ('could', 'situat', 'collect'):0.2
# ('situat', 'collect', 'box'):1.0
# ('collect', 'box', 'offic'):1.0
# ('box', 'offic', 'mind'):0.5
# ('offic', 'mind', 'blow'):0.5
# ('mind', 'blow', 'credit'):0.3333333333333333
# ('blow', 'credit', 'goe'):1.0
# ('credit', 'goe', 'thalapathi'):1.0
# ('goe', 'thalapathi', 'review'):0.5
# ('thalapathi', 'review', 'posit'):0.0196078431372549
# ('review', 'posit', 'review'):0.16666666666666666
# ('posit', 'review', 'float'):0.2
# ('review', 'float', 'world'):0.16666666666666666
# ('float', 'world', 'master'):1.0
# ('world', 'master', 'became1st'):1.0
# ('master', 'became1st', 'ever'):0.023255813953488372
# ('became1st', 'ever', 'blockbust'):1.0
# ('ever', 'blockbust', 'film'):0.5
# ('blockbust', 'film', '2021'):0.1111111111111111
# ('film', '2021', 'thalapathi'):0.015873015873015872
# ('2021', 'thalapathi', 'act'):1.0
# ('thalapathi', 'act', 'extraordinari'):0.0196078431372549
# ('act', 'extraordinari', 'charm'):0.03571428571428571
# ('extraordinari', 'charm', 'vijaysethupathi'):0.5
# ('charm', 'vijaysethupathi', 'havana'):0.5
# ('vijaysethupathi', 'havana', 'steal'):0.25
# ('havana', 'steal', 'show'):0.07142857142857142
# ('steal', 'show', 'one'):0.5
# ('show', 'one', 'great'):0.1
# ('one', 'great', 'vile'):0.05263157894736842
# ('great', 'vile', 'villain'):0.06666666666666667
# ('vile', 'villain', 'recent'):0.3333333333333333
# ('villain', 'recent', 'time'):0.05555555555555555
# ('recent', 'time', 'anirudh'):0.5
# ('time', 'anirudh', 'by'):0.05
# ('taken', 'hollywood', 'level'):0.5
# ('hollywood', 'level', 'amaz'):0.5
# ('level', 'amaz', 'musicsong'):0.08333333333333333
# ('amaz', 'musicsong', 'dirlokesh'):0.14285714285714285
# ('musicsong', 'dirlokesh', 'awesom'):1.0
# ('dirlokesh', 'awesom', 'screenplay'):1.0
# ('awesom', 'screenplay', 'direct'):0.07692307692307693
# ('screenplay', 'direct', 'make'):0.07692307692307693
# ('direct', 'make', 'u'):0.08333333333333333
# ('make', 'u', 'edg'):0.05555555555555555
# ('u', 'edg', 'seat'):0.09090909090909091
# ('edg', 'seat', 'veryimport'):1.0
# ('seat', 'veryimport', 'role'):0.5
# ('veryimport', 'role', 'arjunda'):1.0
# ('role', 'arjunda', 'fantast'):0.06666666666666667
# ('arjunda', 'fantast', 'thrill'):1.0
# ('fantast', 'thrill', 'film'):0.2
# ('thrill', 'film', 'verdict'):0.5
# ('film', 'verdict', 'definit'):0.015873015873015872
# ('verdict', 'definit', 'huge'):0.5
# ('definit', 'huge', 'blockbust'):0.2
# ('huge', 'blockbust', 'master'):0.3333333333333333
# ('blockbust', 'master', 'master'):0.1111111111111111
# ('master', 'master', 'papa'):0.023255813953488372
# ('master', 'papa', 'mass'):0.023255813953488372
# ('papa', 'mass', 'blockbust'):0.5
# ('mass', 'blockbust', 'd'):0.038461538461538464
# ('blockbust', 'd', 'v'):0.1111111111111111
# ('d', 'v', 'havana'):0.25
# ('v', 'havana', 'kavalan'):0.02857142857142857
# ('havana', 'kavalan', 'thuppaki'):0.07142857142857142
# ('kavalan', 'thuppaki', 'vital'):1.0
# ('thuppaki', 'vital', 'differ'):0.5
# ('vital', 'differ', 'shade'):0.015503875968992248
# ('differ', 'shade', 'vital'):0.05
# ('shade', 'vital', 'shown'):0.3333333333333333
# ('vital', 'shown', 'new'):0.007751937984496124
# ('shown', 'new', 'mannerismcool'):0.3333333333333333
# ('new', 'mannerismcool', 'swag'):0.125
# ('mannerismcool', 'swag', 'vijaysethupathi'):1.0
# ('swag', 'vijaysethupathi', 'score'):0.3333333333333333
# ('vijaysethupathi', 'score', 'traffic'):0.25
# ('score', 'traffic', 'villain'):0.1111111111111111
# ('traffic', 'villain', 'act'):1.0
# ('villain', 'act', 'love'):0.05555555555555555
# ('act', 'love', 'perfectli'):0.03571428571428571
# ('love', 'perfectli', 'balanc'):0.02127659574468085
# ('perfectli', 'balanc', 'script'):0.3333333333333333
# ('balanc', 'script', 'need'):0.5
# ('script', 'need', 'multi'):0.25
# ('need', 'multi', 'star'):0.5
# ('multi', 'star', 'film'):1.0
# ('star', 'film', 'postal'):0.16666666666666666
# ('film', 'postal', 'treat'):0.015873015873015872
# ('postal', 'treat', 'everyon'):0.14285714285714285
# ('treat', 'everyon', 'onli'):0.14285714285714285
# ('everyon', 'onli', 'neg'):0.16666666666666666
# ('onli', 'neg', 'and'):1.0
# ('neg', 'and', 'length'):0.1111111111111111
# ('and', 'length', 'scene'):0.07692307692307693
# ('length', 'scene', 'trim'):0.3333333333333333
# ('scene', 'trim', 'mean'):0.05
# ('trim', 'mean', 'would'):1.0
# ('mean', 'would', 'better'):0.5
# ('would', 'better', 'lit'):0.1111111111111111
# ('better', 'lit', 'rage'):0.16666666666666666
# ('lit', 'rage', 'by'):0.5
# ('rage', 'by', 'thalapathi'):0.5
# ('by', 'thalapathi', 'makkalselvan'):0.05
# ('thalapathi', 'makkalselvan', 'd'):0.0196078431372549
# ('makkalselvan', 'd', 'v'):1.0
# ('v', 'havana', 'super'):0.02857142857142857
# ('havana', 'super', 'movi'):0.07142857142857142
# ('super', 'movi', 'visual'):0.2
# ('movi', 'visual', 'effect'):0.008264462809917356
# ('visual', 'effect', 'movi'):0.3333333333333333
# ('effect', 'movi', 'by'):0.5
# ('movi', 'by', 'sound'):0.008264462809917356
# ('by', 'sound', 'danc'):0.05
# ('sound', 'danc', 'movement'):0.3333333333333333
# ('danc', 'movement', 'excel'):0.5
# ('movement', 'excel', 'director'):1.0
# ('excel', 'director', 'show'):0.2
# ('director', 'show', 'differ'):0.07692307692307693
# ('show', 'differ', 'angl'):0.1
# ('differ', 'angl', 'vital'):0.05
# ('angl', 'vital', 'andvjiay'):1.0
# ('vital', 'andvjiay', 'sethupathi'):0.007751937984496124
# ('andvjiay', 'sethupathi', 'cinephil'):1.0
# ('sethupathi', 'cinephil', 'wait'):0.030303030303030304
# ('cinephil', 'wait', 'long'):1.0
# ('wait', 'long', 'around'):0.3333333333333333
# ('long', 'around', '1'):0.1111111111111111
# ('around', '1', 'year'):0.1111111111111111
# ('1', 'year', 'wait'):0.3333333333333333
# ('year', 'wait', 'see'):0.16666666666666666
# ('wait', 'see', 'movi'):0.3333333333333333
# ('see', 'movi', 'big'):0.1111111111111111
# ('movi', 'big', 'screen'):0.008264462809917356
# ('big', 'screen', 'final'):0.1111111111111111
# ('screen', 'final', 'happen'):0.058823529411764705
# ('final', 'happen', 'master'):0.25
# ('happen', 'master', 'film'):1.0
# ('master', 'film', 'film'):0.023255813953488372
# ('film', 'film', 'pure'):0.015873015873015872
# ('film', 'pure', 'entertain'):0.015873015873015872
# ('pure', 'entertain', 'movi'):0.16666666666666666
# ('entertain', 'movi', 'small'):0.034482758620689655
# ('movi', 'small', 'script'):0.008264462809917356
# ('small', 'script', 'execut'):1.0
# ('script', 'execut', 'theatr'):0.25
# ('execut', 'theatr', 'experi'):1.0
# ('theatr', 'experi', 'good'):0.1
# ('experi', 'good', 'mani'):0.16666666666666666
# ('good', 'mani', 'goosebump'):0.03225806451612903
# ('mani', 'goosebump', 'moment'):0.2
# ('goosebump', 'moment', 'movi'):0.5
# ('moment', 'movi', 'vital'):0.14285714285714285
# ('movi', 'vital', 'done'):0.008264462809917356
# ('vital', 'done', 'great'):0.007751937984496124
# ('done', 'great', 'act'):0.1111111111111111
# ('great', 'act', 'new'):0.06666666666666667
# ('act', 'new', 'manner'):0.03571428571428571
# ('new', 'manner', 'vital'):0.125
# ('manner', 'vital', 'sethupathi'):0.1
# ('vital', 'sethupathi', 'noth'):0.007751937984496124
# ('sethupathi', 'noth', 'say'):0.030303030303030304
# ('noth', 'say', 'pure'):1.0
# ('say', 'pure', 'villain'):0.2
# ('pure', 'villain', 'made'):0.16666666666666666
# ('villain', 'made', 'watch'):0.05555555555555555
# ('made', 'watch', 'till'):0.1
# ('watch', 'till', 'go'):0.02040816326530612
# ('till', 'go', 'watch'):0.25
# ('go', 'watch', 'theatr'):0.125
# ('watch', 'theatr', 'e'):0.02040816326530612
# ('theatr', 'e', 'theater'):0.1
# ('e', 'theater', 'experi'):0.3333333333333333
# ('theater', 'experi', 'movi'):0.14285714285714285
# ('experi', 'movi', 'vital'):0.16666666666666666
# ('vital', 'v', 'love'):0.007751937984496124
# ('v', 'love', 'and'):0.02857142857142857
# ('love', 'and', 'done'):0.02127659574468085
# ('and', 'done', 'fantabul'):0.07692307692307693
# ('done', 'fantabul', 'job'):0.1111111111111111
# ('fantabul', 'job', 'hero'):0.5
# ('job', 'hero', 'villain'):0.2
# ('hero', 'villain', 'fine'):0.1
# ('villain', 'fine', 'make'):0.05555555555555555
# ('fine', 'make', 'movi'):1.0
# ('make', 'movi', 'intens'):0.05555555555555555
# ('movi', 'intens', 'watch'):0.008264462809917356
# ('intens', 'watch', 'big'):0.3333333333333333
# ('watch', 'big', 'screen'):0.02040816326530612
# ('big', 'screen', 'super'):0.1111111111111111
# ('screen', 'super', 'theatr'):0.058823529411764705
# ('super', 'theatr', 'experi'):0.2
# ('theatr', 'experi', 'movi'):0.1
# ('experi', 'movi', 'satisfi'):0.16666666666666666
# ('movi', 'satisfi', 'famili'):0.008264462809917356
# ('satisfi', 'famili', 'audienc'):0.3333333333333333
# ('famili', 'audienc', 'thalapathi'):0.5
# ('audienc', 'thalapathi', 'fansthi'):0.125
# ('thalapathi', 'fansthi', 'differ'):0.0196078431372549
# ('fansthi', 'differ', 'usual'):1.0
# ('differ', 'usual', 'thalapathi'):0.05
# ('usual', 'thalapathi', 'movi'):0.2
# ('thalapathi', 'movi', 'charact'):0.0196078431372549
# ('movi', 'charact', 'uniqu'):0.008264462809917356
# ('charact', 'uniqu', 'movi'):0.05
# ('uniqu', 'movi', 'super'):0.16666666666666666
# ('super', 'movi', 'everi'):0.2
# ('movi', 'everi', 'one'):0.008264462809917356
# ('everi', 'one', 'enjoy'):0.25
# ('one', 'enjoy', 've'):0.05263157894736842
# ('enjoy', 've', 'differ'):0.05263157894736842
# ('ve', 'differ', 'role'):0.1111111111111111
# ('differ', 'role', 'worth'):0.05
# ('role', 'worth', 'watch'):0.06666666666666667
# ('worth', 'watch', 'theatr'):0.09090909090909091
# ('watch', 'theatr', '9'):0.02040816326530612
# ('theatr', '9', 'month'):0.1
# ('9', 'month', 'must'):1.0
# ('month', 'must', 'watch'):0.5
# ('must', 'watch', 'movi'):0.16666666666666666
# ('watch', 'movi', 'act'):0.02040816326530612
# ('movi', 'act', 'gone'):0.008264462809917356
# ('act', 'gone', 'next'):0.03571428571428571
# ('gone', 'next', 'level'):1.0
# ('next', 'level', 'vital'):0.25
# ('level', 'vital', 'sethupathi'):0.08333333333333333
# ('vital', 'sethupathi', 'done'):0.007751937984496124
# ('sethupathi', 'done', 'great'):0.030303030303030304
# ('done', 'great', 'job'):0.1111111111111111
# ('great', 'job', 'captain'):0.06666666666666667
# ('job', 'captain', 'ship'):0.2
# ('captain', 'ship', 'love'):1.0
# ('ship', 'love', 'appreci'):1.0
# ('love', 'appreci', 'fulli'):0.02127659574468085
# ('appreci', 'fulli', 'enjoy'):0.25
# ('fulli', 'enjoy', 'awesom'):1.0
# ('enjoy', 'awesom', 'action'):0.05263157894736842
# ('awesom', 'action', 'scene'):0.07692307692307693
# ('action', 'scene', 'theatr'):0.05263157894736842
# ('scene', 'theatr', 'experi'):0.05
# ('theatr', 'experi', 'ye'):0.1
# ('experi', 'ye', 'movi'):0.16666666666666666
# ('ye', 'movi', 'also'):0.25
# ('movi', 'also', 'minu'):0.008264462809917356
# ('also', 'minu', 'point'):0.07692307692307693
# ('minu', 'point', 'like'):1.0
# ('point', 'like', 'aunti'):0.25
# ('like', 'aunti', 'biggest'):0.05263157894736842
# ('aunti', 'biggest', 'problem'):1.0
# ('biggest', 'problem', 'time'):0.3333333333333333
# ('problem', 'time', 'vital'):0.5
# ('time', 'vital', 'handl'):0.05
# ('vital', 'handl', 'problemand'):0.007751937984496124
# ('handl', 'problemand', 'make'):0.5
# ('problemand', 'make', 'movi'):1.0
# ('make', 'movi', 'awesom'):0.05555555555555555
# ('movi', 'awesom', 'ye'):0.008264462809917356
# ('awesom', 'ye', 'awesom'):0.07692307692307693
# ('ye', 'awesom', 'vital'):0.25
# ('awesom', 'vital', 'make'):0.07692307692307693
# ('vital', 'make', 'movi'):0.007751937984496124
# ('make', 'movi', 'ok'):0.05555555555555555
# ('movi', 'ok', 'ok'):0.008264462809917356
# ('ok', 'ok', 'awesom'):0.2
# ('ok', 'awesom', 'dont'):0.2
# ('awesom', 'dont', 'movi'):0.07692307692307693
# ('dont', 'movi', 'may'):0.125
# ('movi', 'may', 'averag'):0.008264462809917356
# ('may', 'averag', 'flop'):0.3333333333333333
# ('averag', 'flop', 'moviebut'):0.5
# ('flop', 'moviebut', 'ignor'):1.0
# ('moviebut', 'ignor', 'hate'):1.0
# ('ignor', 'hate', 'review'):0.3333333333333333
# ('hate', 'review', 'go'):0.5
# ('review', 'go', 'see'):0.16666666666666666
# ('go', 'see', 'vital'):0.125
# ('see', 'vital', 'v'):0.1111111111111111
# ('v', 'vital', 'best'):0.02857142857142857
# ('vital', 'best', 'hero'):0.007751937984496124
# ('best', 'hero', 'villain'):0.038461538461538464
# ('hero', 'villain', 'flick'):0.1
# ('villain', 'flick', 'vital'):0.05555555555555555
# ('flick', 'vital', 'vital'):1.0
# ('vital', 'vital', 'sethupati'):0.007751937984496124
# ('vital', 'sethupati', 'act'):0.007751937984496124
# ('sethupati', 'act', 'well'):0.5
# ('act', 'well', 'background'):0.03571428571428571
# ('well', 'background', 'music'):0.05
# ('background', 'music', 'good'):0.1
# ('music', 'good', 'cinematographi'):0.07692307692307693
# ('good', 'cinematographi', 'excel'):0.03225806451612903
# ('cinematographi', 'excel', 'complet'):0.5
# ('excel', 'complet', 'show'):0.2
# ('complet', 'show', 'differ'):0.16666666666666666
# ('show', 'differ', 'version'):0.1
# ('differ', 'version', 'thalapathi'):0.05
# ('version', 'thalapathi', 'vital'):1.0
# ('thalapathi', 'vital', 'blockbust'):0.0196078431372549
# ('vital', 'blockbust', 'one'):0.007751937984496124
# ('blockbust', 'one', 'nice'):0.1111111111111111
# ('one', 'nice', 'movi'):0.05263157894736842
# ('nice', 'movi', 'vera'):0.14285714285714285
# ('vera', 'level', 'act'):0.1111111111111111
# ('level', 'act', 'thalapathi'):0.08333333333333333
# ('act', 'thalapathi', 'good'):0.03571428571428571
# ('thalapathi', 'good', 'stori'):0.0196078431372549
# ('good', 'stori', 'line'):0.06451612903225806
# ('stori', 'line', 'v'):0.038461538461538464
# ('line', 'v', 'act'):0.14285714285714285
# ('v', 'act', 'also'):0.02857142857142857
# ('act', 'also', 'good'):0.03571428571428571
# ('also', 'good', 'best'):0.07692307692307693
# ('good', 'best', 'comb'):0.03225806451612903
# ('best', 'comb', 'good'):0.038461538461538464
# ('comb', 'good', 'direct'):0.5
# ('good', 'direct', 'lokessh'):0.03225806451612903
# ('direct', 'lokessh', 'watch'):0.08333333333333333
# ('lokessh', 'watch', 'theater'):1.0
# ('watch', 'theater', 'enjoy'):0.02040816326530612
# ('theater', 'enjoy', 'sound'):0.14285714285714285
# ('enjoy', 'sound', 'effect'):0.05263157894736842
# ('sound', 'effect', 'sea'):0.3333333333333333
# ('effect', 'sea', 'treat'):0.5
# ('sea', 'treat', 'vital'):1.0
# ('treat', 'vital', 'fan'):0.2857142857142857
# ('vital', 'fan', 'pro'):0.007751937984496124
# ...
# ('peopl', 'might', 'feel'):0.14285714285714285
# ('might', 'feel', 'miss'):0.3333333333333333
# ('feel', 'miss', 'whole'):0.25
# ('miss', 'whole', 'vila'):0.14285714285714285
# ('whole', 'vila', 'perform'):0.25
# ('vila', 'perform', 'definit'):0.0625
# ('perform', 'definit', 'one'):0.037037037037037035
# ('definit', 'one', 'best'):0.2
# ('one', 'best', 'career'):0.05263157894736842
# ('best', 'career', 'far'):0.038461538461538464
# ('career', 'far', 'side'):0.25
# ('far', 'side', 'evil'):1.0
# ('side', 'evil', 'havana'):0.3333333333333333
# ('evil', 'havana', 'play'):0.25
# ('havana', 'play', 'vital'):0.07142857142857142
# ('play', 'vital', 'sethupathi'):0.0625
# ('vital', 'sethupathi', 'honestli'):0.007751937984496124
# ('sethupathi', 'honestli', 'vital'):0.030303030303030304
# ('honestli', 'vital', 'sethupathi'):1.0
# ('vital', 'sethupathi', 'perform'):0.015503875968992248
# ('sethupathi', 'perform', 'add'):0.030303030303030304
# ('perform', 'add', 'much'):0.037037037037037035
# ('add', 'much', 'intens'):0.25
# ('much', 'intens', 'film'):0.5
# ('intens', 'film', 'interest'):0.3333333333333333
# ('film', 'interest', 'watch'):0.015873015873015872
# ('interest', 'watch', 'play'):0.25
# ('watch', 'play', 'effortlessli'):0.02040816326530612
# ('play', 'effortlessli', 'wit'):0.0625
# ('effortlessli', 'wit', 'menac'):1.0
# ('wit', 'menac', 'evil'):0.25
# ('menac', 'evil', 'vital'):1.0
# ('evil', 'vital', 'film'):0.25
# ('vital', 'film', 'abl'):0.007751937984496124
# ('film', 'abl', 'pull'):0.015873015873015872
# ('abl', 'pull', 'hero'):0.5
# ('pull', 'hero', 'vile'):1.0
# ('hero', 'vile', 'd'):0.1
# ('vile', 'd', 'sever'):0.3333333333333333
# ('d', 'sever', 'moment'):0.125
# ('sever', 'moment', 'lose'):1.0
# ('moment', 'lose', 'havana'):0.14285714285714285
# ('lose', 'havana', 'make'):0.3333333333333333
# ('havana', 'make', 'overal'):0.07142857142857142
# ('make', 'overal', 'narr'):0.05555555555555555
# ('overal', 'narr', 'interest'):0.07142857142857142
# ('narr', 'interest', 'believ'):1.0
# ('interest', 'believ', 'havana'):0.25
# ('believ', 'havana', 'easili'):1.0
# ('havana', 'easili', 'one'):0.07142857142857142
# ('easili', 'one', 'best'):1.0
# ('one', 'best', 'villain'):0.05263157894736842
# ('best', 'villain', 'tail'):0.038461538461538464
# ('villain', 'tail', 'cinema'):0.05555555555555555
# ('tail', 'cinema', 'vital'):0.25
# ('cinema', 'vital', 'sethupathi'):0.25
# ('sethupathi', 'perform', 'simpli'):0.030303030303030304
# ('perform', 'simpli', 'brilliant'):0.037037037037037035
# ('simpli', 'brilliant', 'one'):0.5
# ('brilliant', 'one', 'disappoint'):0.16666666666666666
# ('one', 'disappoint', 'master'):0.05263157894736842
# ('disappoint', 'master', 'lack'):0.3333333333333333
# ('master', 'lack', 'import'):0.023255813953488372
# ('lack', 'import', 'support'):0.2
# ('import', 'support', 'actor'):0.2
# ('support', 'actor', 'muchexpect'):0.3333333333333333
# ('actor', 'muchexpect', 'actor'):0.1111111111111111
# ('muchexpect', 'actor', 'thought'):1.0
# ('actor', 'thought', 'strong'):0.1111111111111111
# ('thought', 'strong', 'role'):1.0
# ('strong', 'role', 'unfortun'):0.5
# ('role', 'unfortun', 'left'):0.06666666666666667
# ('unfortun', 'left', 'minim'):0.5
# ('left', 'minim', 'screen'):0.3333333333333333
# ('minim', 'screen', 'time'):1.0
# ('screen', 'time', 'le'):0.058823529411764705
# ('time', 'le', 'scope'):0.05
# ('le', 'scope', 'overal'):1.0
# ('scope', 'overal', 'plot'):1.0
# ('overal', 'plot', 'thank'):0.07142857142857142
# ('plot', 'thank', 'around'):0.25
# ('thank', 'around', 'da'):0.3333333333333333
# ('around', 'da', 'poovaiyaar'):0.1111111111111111
# ('da', 'poovaiyaar', 'master'):0.16666666666666666
# ('poovaiyaar', 'master', 'mahendran'):1.0
# ('master', 'mahendran', 'contribut'):0.023255813953488372
# ('mahendran', 'contribut', 'lot'):0.2
# ('contribut', 'lot', 'surpris'):1.0
# ('lot', 'surpris', 'audienc'):0.14285714285714285
# ('surpris', 'audienc', 'brilliant'):0.5
# ('audienc', 'brilliant', 'perform'):0.125
# ('brilliant', 'perform', 'memor'):0.16666666666666666
# ('perform', 'memor', 'role'):0.037037037037037035
# ('memor', 'role', 'faith'):0.5
# ('role', 'faith', 'around'):0.06666666666666667
# ('faith', 'around', 'da'):0.25
# ('around', 'da', 'back'):0.1111111111111111
# ('da', 'back', 'anoth'):0.16666666666666666
# ('back', 'anoth', 'antagonist'):0.5
# ('anoth', 'antagonist', 'film'):0.14285714285714285
# ('antagonist', 'film', 'play'):0.14285714285714285
# ('film', 'play', 'huge'):0.015873015873015872
# ('play', 'huge', 'part'):0.0625
# ('huge', 'part', 'bring'):0.3333333333333333
# ('part', 'bring', 'vital'):0.14285714285714285
# ('bring', 'vital', 'latter'):1.0
# ('vital', 'latter', 'half'):0.007751937984496124
# ('latter', 'half', 'forget'):0.5
# ('half', 'forget', 'around'):0.045454545454545456
# ('forget', 'around', 'day'):0.3333333333333333
# ('around', 'day', 'voic'):0.1111111111111111
# ('day', 'voic', 'add'):0.3333333333333333
# ('voic', 'add', 'muchneed'):0.2
# ('add', 'muchneed', 'vile'):0.25
# ('muchneed', 'vile', 'charact'):1.0
# ('vile', 'charact', 'vital'):0.3333333333333333
# ('charact', 'vital', 'main'):0.05
# ('vital', 'main', 'hero'):0.007751937984496124
# ('main', 'hero', 'poovaiyar'):0.16666666666666666
# ('hero', 'poovaiyar', 'play'):0.1
# ('poovaiyar', 'play', 'second'):0.16666666666666666
# ('play', 'second', 'hero'):0.0625
# ('second', 'hero', 'film'):0.16666666666666666
# ('hero', 'film', 'ye'):0.1
# ('film', 'ye', 'there'):0.015873015873015872
# ('ye', 'there', 'particular'):0.25
# ('there', 'particular', 'scene'):0.16666666666666666
# ('particular', 'scene', 'poovaiyar'):1.0
# ('scene', 'poovaiyar', 'show'):0.05
# ('poovaiyar', 'show', 'heroism'):0.16666666666666666
# ('show', 'heroism', 'vital'):0.1
# ('heroism', 'vital', 'take'):1.0
# ('vital', 'take', 'back'):0.007751937984496124
# ('take', 'back', 'seat'):0.25
# ('back', 'seat', 'definit'):0.5
# ('seat', 'definit', 'delight'):0.5
# ('definit', 'delight', 'watch'):0.2
# ('delight', 'watch', 'screen'):1.0
# ('watch', 'screen', 'manner'):0.02040816326530612
# ('screen', 'manner', 'uniqu'):0.058823529411764705
# ('manner', 'uniqu', 'enjoy'):0.1
# ('uniqu', 'enjoy', 'like'):0.16666666666666666
# ('enjoy', 'like', 'poovaiyar'):0.05263157894736842
# ('like', 'poovaiyar', 'master'):0.05263157894736842
# ('poovaiyar', 'master', 'mahendran'):0.16666666666666666
# ('master', 'mahendran', 'play'):0.023255813953488372
# ('mahendran', 'play', 'surpris'):0.2
# ('play', 'surpris', 'memor'):0.0625
# ('surpris', 'memor', 'role'):0.5
# ('memor', 'role', 'first'):0.5
# ('role', 'first', '15'):0.06666666666666667
# ('first', '15', 'mind'):0.13333333333333333
# ('15', 'mind', 'film'):0.5
# ('mind', 'film', 'phenomenon'):0.3333333333333333
# ('film', 'phenomenon', 'anirudh'):0.015873015873015872
# ('phenomenon', 'anirudh', 'background'):0.3333333333333333
# ('anirudh', 'background', 'score'):0.07142857142857142
# ('background', 'score', 'song'):0.1
# ('score', 'song', 'huge'):0.1111111111111111
# ('song', 'huge', 'pillar'):0.07692307692307693
# ('huge', 'pillar', 'film'):0.3333333333333333
# ('pillar', 'film', 'add'):0.5
# ('film', 'add', 'much'):0.015873015873015872
# ('add', 'much', 'color'):0.25
# ('much', 'color', 'power'):0.5
# ('color', 'power', 'film'):0.5
# ('power', 'film', 'even'):0.25
# ('film', 'even', 'help'):0.015873015873015872
# ('even', 'help', 'lift'):0.16666666666666666
# ('help', 'lift', 'mass'):1.0
# ('lift', 'mass', 'screen'):0.5
# ('mass', 'screen', 'presenc'):0.038461538461538464
# ('screen', 'presenc', 'vital'):0.058823529411764705
# ('presenc', 'vital', 'vital'):0.25
# ('vital', 'sethupathi', 'festiv'):0.007751937984496124
# ('sethupathi', 'festiv', 'mode'):0.030303030303030304
# ('festiv', 'mode', 'creator'):1.0
# ('mode', 'creator', 'vaathi'):1.0
# ('creator', 'vaathi', 'come'):1.0
# ('vaathi', 'come', 'motiv'):0.16666666666666666
# ('come', 'motiv', 'tutti'):0.125
# ('motiv', 'tutti', 'stori'):1.0
# ('tutti', 'stori', 'place'):1.0
# ('stori', 'place', 'well'):0.038461538461538464
# ('place', 'well', 'film'):0.25
# ('well', 'film', 'usual'):0.05
# ('film', 'usual', 'plea'):0.015873015873015872
# ('usual', 'plea', 'special'):0.2
# ('plea', 'special', 'mention'):0.3333333333333333
# ('special', 'mention', 'amaz'):0.5
# ('mention', 'amaz', 'remain'):0.3333333333333333
# ('amaz', 'remain', 'kabaddi'):0.14285714285714285
# ('remain', 'kabaddi', 'song'):0.5
# ('kabaddi', 'song', 'hill'):0.3333333333333333
# ('song', 'hill', 'action'):0.07692307692307693
# ('hill', 'action', 'sequenc'):0.5
# ('action', 'sequenc', 'master'):0.05263157894736842
# ('sequenc', 'master', 'ground'):0.14285714285714285
# ('master', 'ground', 'slightli'):0.023255813953488372
# ('ground', 'slightli', 'realist'):0.5
# ('slightli', 'realist', 'like'):0.5
# ('realist', 'like', 'love'):0.5
# ('like', 'love', 'said'):0.05263157894736842
# ('love', 'said', 'promot'):0.02127659574468085
# ('said', 'promot', 'interview'):0.5
# ('promot', 'interview', 'especi'):1.0
# ('interview', 'especi', 'interv'):0.5
# ('especi', 'interv', 'fight'):1.0
# ('interv', 'fight', 'kabaddi'):0.25
# ('fight', 'kabaddi', 'fight'):0.08333333333333333
# ('kabaddi', 'fight', 'climax'):0.3333333333333333
# ('fight', 'climax', 'fight'):0.08333333333333333
# ('climax', 'fight', 'strictli'):0.16666666666666666
# ('fight', 'strictli', 'fan'):0.08333333333333333
# ('strictli', 'fan', 'moment'):1.0
# ('fan', 'moment', 'stung'):0.03333333333333333
# ('moment', 'stung', 'choreographi'):0.14285714285714285
# ('stung', 'choreographi', 'retro'):0.3333333333333333
# ('choreographi', 'retro', 'fight'):1.0
# ('retro', 'fight', 'fresh'):1.0
# ('fight', 'fresh', 'well'):0.08333333333333333
# ('fresh', 'well', 'done'):0.5
# ('well', 'done', 'climax'):0.05
# ('done', 'climax', 'fight'):0.1111111111111111
# ('climax', 'fight', 'vital'):0.16666666666666666
# ('fight', 'vital', 'vital'):0.08333333333333333
# ('vital', 'sethupathi', 'rememb'):0.007751937984496124
# ('sethupathi', 'rememb', 'forev'):0.030303030303030304
# ('rememb', 'forev', 'equal'):1.0
# ('forev', 'equal', 'import'):1.0
# ('equal', 'import', 'screen'):0.3333333333333333
# ('import', 'screen', 'impress'):0.2
# ('screen', 'impress', 'manner'):0.058823529411764705
# ('impress', 'manner', 'person'):1.0
# ('manner', 'person', 'felt'):0.1
# ('felt', 'master', 'issu'):0.25
# ('master', 'issu', 'run'):0.023255813953488372
# ('issu', 'run', 'time'):0.5
# ('run', 'time', 'watch'):0.5
# ('time', 'watch', 'film'):0.05
# ('watch', 'film', '3'):0.02040816326530612
# ('film', '3', 'hour'):0.015873015873015872
# ('3', 'hour', 'easi'):0.25
# ('hour', 'easi', 'there'):0.3333333333333333
# ('easi', 'there', 'big'):1.0
# ('there', 'big', 'chanc'):0.16666666666666666
# ('big', 'chanc', 'lose'):0.1111111111111111
# ('chanc', 'lose', 'patienc'):1.0
# ('lose', 'patienc', 'initi'):0.3333333333333333
# ('patienc', 'initi', 'that'):1.0
# ('initi', 'that', 'main'):1.0
# ('that', 'main', 'problem'):0.5
# ('main', 'problem', 'master'):0.16666666666666666
# ('problem', 'master', 'there'):0.5
# ('master', 'there', 'scene'):0.023255813953488372
# ('there', 'scene', 'could'):0.16666666666666666
# ('scene', 'could', 'cut'):0.05
# ('could', 'cut', 'make'):0.2
# ('cut', 'make', 'film'):1.0
# ('make', 'film', 'race'):0.05555555555555555
# ('film', 'race', 'engag'):0.015873015873015872
# ('race', 'engag', 'also'):0.5
# ('engag', 'also', 'felt'):0.25
# ('also', 'felt', 'emot'):0.07692307692307693
# ('felt', 'emot', 'conduct'):0.25
# ('emot', 'conduct', 'didn'):0.16666666666666666
# ('conduct', 'didn', 'work'):1.0
# ('didn', 'work', 'film'):0.2
# ('work', 'film', 'scene'):0.125
# ('film', 'scene', 'vital'):0.015873015873015872
# ('scene', 'vital', 'cri'):0.05
# ('vital', 'cri', 'first'):0.007751937984496124
# ('cri', 'first', 'time'):1.0
# ('first', 'time', 'jail'):0.06666666666666667
# ('time', 'jail', 'great'):0.05
# ('jail', 'great', 'perform'):0.5
# ('great', 'perform', 'left'):0.06666666666666667
# ('perform', 'left', 'ineffect'):0.037037037037037035
# ('left', 'ineffect', 'let'):0.3333333333333333
# ('ineffect', 'let', 'come'):1.0
# ('let', 'come', 'love'):1.0
# ('come', 'love', 'kanagaraj'):0.125
# ('love', 'kanagaraj', 'previou'):0.02127659574468085
# ('kanagaraj', 'previou', 'interview'):0.1111111111111111
# ('previou', 'interview', 'mention'):0.14285714285714285
# ('interview', 'mention', 'clearli'):0.5
# ('mention', 'clearli', 'film'):0.3333333333333333
# ('clearli', 'film', '50'):0.5
# ('film', '50', 'vital'):0.015873015873015872
# ('50', 'vital', 'film'):0.2
# ('vital', 'film', '50'):0.007751937984496124
# ('film', '50', 'love'):0.015873015873015872
# ('love', 'film', 'well'):0.02127659574468085
# ('film', 'well', 'watch'):0.015873015873015872
# ('well', 'watch', 'master'):0.05
# ('watch', 'master', 'realli'):0.02040816326530612
# ('master', 'realli', 'feel'):0.023255813953488372
# ('realli', 'feel', 'right'):0.1
# ('feel', 'right', 'fan'):0.25
# ('right', 'fan', 'moment'):1.0
# ('fan', 'moment', 'iron'):0.03333333333333333
# ('moment', 'iron', 'vital'):0.14285714285714285
# ('iron', 'vital', 'manner'):1.0
# ('vital', 'manner', 'ad'):0.007751937984496124
# ('manner', 'ad', 'satisfi'):0.1
# ('ad', 'satisfi', 'core'):0.25
# ('satisfi', 'core', 'vital'):0.3333333333333333
# ('core', 'vital', 'fan'):0.25
# ('vital', 'fan', 'like'):0.007751937984496124
# ('fan', 'like', 'kabaddi'):0.03333333333333333
# ('like', 'kabaddi', 'fight'):0.05263157894736842
# ('kabaddi', 'fight', 'major'):0.3333333333333333
# ('fight', 'major', 'throwback'):0.08333333333333333
# ('major', 'throwback', 'vila'):1.0
# ('throwback', 'vila', 'hill'):1.0
# ('vila', 'hill', 'also'):0.0625
# ('hill', 'also', 'ad'):0.5
# ('also', 'ad', 'wellknown'):0.07692307692307693
# ('ad', 'wellknown', 'director'):0.25
# ('wellknown', 'director', 'signatur'):1.0
# ('director', 'signatur', 'like'):0.07692307692307693
# ('signatur', 'like', 'first'):0.5
# ('like', 'first', '15'):0.05263157894736842
# ('15', 'mind', 'use'):0.5
# ('mind', 'use', 'introduc'):0.3333333333333333
# ('use', 'introduc', 'antagonist'):0.16666666666666666
# ('introduc', 'antagonist', 'establish'):1.0
# ('antagonist', 'establish', 'main'):0.14285714285714285
# ('establish', 'main', 'core'):0.5
# ('main', 'core', 'plot'):0.16666666666666666
# ('core', 'plot', 'film'):0.25
# ('plot', 'film', 'director'):0.25
# ('film', 'director', 'love'):0.015873015873015872
# ('director', 'love', 'deliv'):0.07692307692307693
# ('love', 'deliv', 'film'):0.02127659574468085
# ('deliv', 'film', 'would'):0.5
# ('film', 'would', 'satisfi'):0.015873015873015872
# ('would', 'satisfi', 'vital'):0.1111111111111111
# ('satisfi', 'vital', 'fan'):0.3333333333333333
# ('vital', 'fan', 'in'):0.007751937984496124
# ('fan', 'in', 'sure'):0.03333333333333333
# ('in', 'sure', 'would'):0.5
# ('sure', 'would', 'work'):0.125
# ('would', 'work', 'fan'):0.1111111111111111
# ('work', 'fan', 'love'):0.125
# ('fan', 'love', 'previou'):0.03333333333333333
# ('love', 'previou', 'work'):0.02127659574468085
# ('previou', 'work', 'term'):0.14285714285714285
# ('work', 'term', 'write'):0.125
# ('term', 'write', 'master'):1.0
# ('write', 'master', 'shine'):0.5
# ('master', 'shine', 'place'):0.023255813953488372
# ('shine', 'place', 'moment'):1.0
# ('place', 'moment', 'left'):0.25
# ('moment', 'left', 'unimpact'):0.14285714285714285
# ('left', 'unimpact', 'due'):0.3333333333333333
# ('unimpact', 'due', 'fact'):1.0
# ('due', 'fact', 'there'):0.5
# ('fact', 'there', 'lot'):1.0
# ('there', 'lot', 'compromis'):0.16666666666666666
# ('lot', 'compromis', 'love'):0.14285714285714285
# ('compromis', 'love', 'make'):1.0
# ('love', 'make', 'vital'):0.02127659574468085
# ('make', 'vital', 'overal'):0.05555555555555555
# ('vital', 'overal', 'master'):0.007751937984496124
# ('overal', 'master', 'film'):0.07142857142857142
# ('master', 'film', 'mainli'):0.023255813953488372
# ('film', 'mainli', 'depend'):0.015873015873015872
# ('mainli', 'depend', 'brilliant'):0.3333333333333333
# ('depend', 'brilliant', 'perform'):1.0
# ('brilliant', 'perform', 'vital'):0.16666666666666666
# ('perform', 'vital', 'vital'):0.037037037037037035
# ('vital', 'sethupathi', 'keep'):0.007751937984496124
# ('sethupathi', 'keep', 'engag'):0.030303030303030304
# ('keep', 'engag', 'till'):0.25
# ('engag', 'till', 'end'):0.25
# ('till', 'end', 'word'):0.25
# ('end', 'word', 'full'):0.3333333333333333
# ('word', 'full', 'entertain'):0.5
# ('full', 'entertain', 'talapathay'):0.3333333333333333
# ('entertain', 'talapathay', 'vital'):0.034482758620689655
# ('talapathay', 'vital', 'rock'):1.0
# ('vital', 'rock', 'master'):0.007751937984496124
# ('rock', 'master', 'truli'):0.2
# ('master', 'truli', 'master'):0.023255813953488372

# %%
whole_dataset = ''
index = []
i = 1
for line in dataframe['Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in dataframe['Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in dataframe['Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#             perfect characterist  ...  vital rock master truli master
# Review-1                     1.0  ...                             0.0
# Review-2                     0.0  ...                             0.0
# Review-3                     0.0  ...                             0.0
# Review-4                     0.0  ...                             0.0
# Review-5                     0.0  ...                             0.0
# ...                          ...  ...                             ...
# Review-121                   0.0  ...                             0.0
# Review-122                   0.0  ...                             0.0
# Review-123                   0.0  ...                             0.0
# Review-124                   0.0  ...                             0.0
# Review-125                   0.0  ...                             1.0
#
# [125 rows x 607 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# To build the documents-terms weights (tf*idf) matrix bold text.

import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = dataframe["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda y : tf_idf_value(i,y))
  count+=1

tf_idf
# Out:
#           token         0         1  ...       122       123       124
# 0                0.083231  0.128755  ...  0.149787  0.013021  0.244136
# 1       1sthalf  0.000000  0.128755  ...  0.000000  0.000000  0.000000
# 2        person  0.000000  0.000000  ...  0.000000  0.013021  0.000000
# 3           act  0.083231  0.000000  ...  0.149787  0.013021  0.000000
# 4      charming  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# ...         ...       ...       ...  ...       ...       ...       ...
# 1125     unique  0.000000  0.000000  ...  0.000000  0.013021  0.000000
# 1126    praises  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1127  celebrate  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1128        yes  0.000000  0.000000  ...  0.000000  0.013021  0.000000
# 1129       call  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [1130 rows x 126 columns]

# %%
#Raising Cosine
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
query_sen = 'Perfect characteristation for both VIJAY & VJS. 2nd half is little bit lagging without no story move.Except that VJ mannerism makes u crazy also VJS Terrorism ll haunt u.Worth Watching not like other Thalapathy Movies. Vijay just given up his image & allowed everyone to mock him Its a sign of selfless actor.Climax & interval block was terrific.Dont listen to negative reviews.Its a pure commercial entertainment & decent watchable'
X_list = word_tokenize(query_sen)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine
similarity_list = []
for sentence in dataframe['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(dataframe['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0    Perfect characteristation for both VIJAY & VJS...           0.62361
# 1    Vijay & VJS is Only Lifting The Whole Movie. A...                 0
# 2    Great thing is about the movie is VIJAY vs VIJ...         0.0851257
# 3                                                                   None
# 4                                                                   None
# ..                                                 ...               ...
# 120  Master's biggest plus point is vijay sethupath...          0.049029
# 121  The film is the story of JD (Thalapathy Vijay)...         0.0324785
# 122  LEGEND VS LEGEND.... definitely movie is Epic....         0.0331133
# 123  After proving his mettle as a filmmaker in his...         0.0692543
# 124  No words full on entertainment. Talapathay Vij...          0.051031
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link:
